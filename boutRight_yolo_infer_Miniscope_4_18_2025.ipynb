# %% [markdown]
# # boutRight Code Description
#
# The boutRight project processes bird song recordings to detect and classify bouts using a YOLOv5 model. The code is divided into two main parts:
#
# ## Part 1: Setup and Function Definitions
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `glob`, `shutil`, `torch`, `PIL`, `numpy`, `scipy`, `tqdm`, `io`, `IPython.display`, `concurrent.futures`, `uuid`, `pandas`, and `math`.
#
# 2. **Load YOLOv5 Model**: The YOLOv5 model is loaded with custom weights for detecting bouts in spectrogram images.
#
# 3. **Define Functions**:
#     - `filtered_spectrogram`: Filters and generates a spectrogram from a given audio file. It applies a Butterworth filter, normalizes the signal, and calculates the spectrogram.
#     - `check_for_bouts`: Generates a spectrogram image, uses the YOLOv5 model to detect bouts, and returns the detection results.
#     - `process_wav_file`: Processes each WAV file, moves it to the appropriate directory (`Songs` or `Noise_Calls`), and appends the detection results to CSV files.
#     - `append_to_csv`: Appends detection results to a CSV file, ensuring consistent data formatting.
#     - `get_all_wav_files`: Retrieves all WAV files in a directory, including subdirectories.
#     - `is_already_scanned`: Checks if a file has already been scanned by looking it up in a list of scanned files.
#
# ## Part 2: Processing Bird Song Recordings
#
# 1. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 2. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories and creates them if they don't exist.
#     - It loads the list of already scanned files from `wav_scanned.csv` if available.
#
# 3. **Process WAV Files**:
#     - The script retrieves all WAV files in the hatch day folder, including subdirectories.
#     - It uses a thread pool to process each WAV file concurrently.
#     - For each file, it generates a spectrogram, detects bouts using the YOLOv5 model, and categorizes the files into `Songs` or `Noise_Calls`.
#     - Detection results are appended to `results_bouts.csv` and `results_calls.csv`.
#
# 4. **Handle Duplicates**:
#     - If a file has already been scanned and is detected as a duplicate, a warning is displayed, and the file is deleted.
#
# 5. **Save Scanned Files**:
#     - The list of scanned files is saved to `wav_scanned.csv` to keep track of processed files and avoid reprocessing.
#
# ## Summary
#
# This script is essential for preprocessing and analyzing bird song recordings, enabling the detection and classification of bouts. It ensures efficient processing, categorization, and management of bird song data, facilitating further analysis and research.

# %% [markdown]
# Code below is to limit cpu usage to prevent crashing.

# %%
import psutil
import os

p = psutil.Process(os.getpid())
# Limit to CPU cores 0, 1, 2, 3 (first 4 cores)
p.cpu_affinity([0])

# %%
import os
from glob import glob
import shutil
import torch
from PIL import Image
import numpy as np
from scipy.io import wavfile
from scipy import signal
from tqdm import tqdm
import io
from IPython.display import clear_output
import concurrent.futures
import uuid
import pandas as pd
import math
import zipfile
import warnings
import threading
import hashlib

# Initialize a lock object
lock = threading.Lock()

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'custom', path=os.path.join(os.getcwd(),r'yolov5\runs\train\exp13\weights\best.pt'))
#folder to temporarily save images for YOLO detection
#this is needed to run parallel computing without problems
temp_path = r'C:\Temp'

# Function to filter and generate spectrogram
def filtered_spectrogram(filepath):
    # Length of FFT
    lend = 34
    # Overlap of FFT
    overlap = 33
    # Time length for exponential window of FFT
    ts = 3
    # Low cut frequency in Hz
    lc = 500
    # High cut frequency in Hz
    hc = 20000
    # Color of image settings
    # Contribution of each channel to color
    RGBch = [0.8, 1.5, 1.5]

    # Import the audio data
    fs, data = wavfile.read(filepath)
    # Round length of data and overlap
    lend = round((lend / 1E3) * fs)
    overlap = round((overlap / 1E3) * fs)
    # Next power of two definition
    def nextpow2(x):
        return 1 if x == 0 else 2**math.ceil(math.log2(x))
    # Calculate next power of two
    nfft = nextpow2(lend)

    # Butterworth filter
    def butter_bp(data, lc, hc, fs, order=3):
        nyq = 0.5 * fs
        low = lc / nyq
        high = hc / nyq
        b, a = signal.butter(order, [low, high], btype='band')
        data_filtered = signal.lfilter(b, a, data)
        return data_filtered

    data = butter_bp(data, lc, hc, fs, order=5)
    # Normalize signal
    data = data / max(abs(data))
    # Make windows for spectrogram
    t = np.linspace(-lend / 2 + 1, lend / 2, num=lend)
    sigma = (ts / 1E3) * fs
    w = np.exp(-(t / sigma)**2)
    dw = np.exp(-(t / (2 * sigma))**2)
    # Calculate spectrograms
    [f, t, sx] = signal.spectrogram(data, fs=fs, window=w, noverlap=overlap, nfft=nfft)
    [_, _, sxx] = signal.spectrogram(data, fs=fs, window=dw, noverlap=overlap, nfft=nfft)
    # Average of both spectrograms
    image_array = np.log2(abs(sx) + abs(sxx)) / 2
    # Obtain thresholds for background
    minmax = [np.percentile(image_array, 80), np.percentile(image_array, 99)]
    # Subtract background
    image_array = np.minimum(image_array, minmax[1])
    image_array = np.maximum(image_array, minmax[0])
    # Normalize
    image_array = (image_array - np.min(image_array)) / (np.max(image_array) - np.min(image_array))
    # Flip spectrogram
    image_array = np.flip(image_array, 0)
    # Convert to color
    sz = (image_array.shape[0] - 1, image_array.shape[1] - 1, 3)
    image_color = np.zeros(sz)
    tmp = image_array
    image_color[:, :, 0] = RGBch[0] * tmp[0:-1, 0:-1]
    tmp = np.diff(image_array, 1, axis=0)
    image_color[:, :, 1] = RGBch[1] * tmp[:, 0:-1]
    tmp = np.diff(image_array, 1, axis=1)
    image_color[:, :, 2] = RGBch[2] * tmp[0:-1, :]
    
    return image_color, fs, len(data)

# Function to generate spectrogram and check for bouts using YOLOv5
def check_for_bouts(wav_file, temp_path):
    temp_img_path = None
    try:
        # Ensure the temp_path directory exists
        os.makedirs(temp_path, exist_ok=True)
        
        # Generate the spectrogram and convert it to an image
        spectrogram, fs, data_length = filtered_spectrogram(wav_file)
        spectrogram_image = (spectrogram * 255).astype(np.uint8)
        pil_image = Image.fromarray(spectrogram_image)
        
        # Generate a unique filename for the temporary spectrogram image in the temp_path directory
        temp_img_filename = f'temp_spectrogram_{uuid.uuid4().hex}.png'
        temp_img_path = os.path.join(temp_path, temp_img_filename)
        pil_image.save(temp_img_path)
        
        # Verify the saved image
        with Image.open(temp_img_path) as img:
            img.verify()
        
        # Use YOLOv5 to detect bouts in the spectrogram image
        results = model(temp_img_path)
        
        # Filter detections to only include bouts (class 0)
        bouts = [bbox for bbox in results.xyxy[0] if bbox[5] == 0]
        
        # Check if any bouts are detected
        return len(bouts) > 0, results.xyxy[0], spectrogram.shape[1], data_length, fs
    except ValueError as e:
        if "File format" in str(e):
            print(f"Error in check_for_bouts for {wav_file}: {e}")
        else:
            raise e  # Re-raise other types of ValueErrors
        return False, [], 0, 0, 0
    except Exception as e:
        print(f"Error in check_for_bouts for {wav_file}: {e}")
        return False, [], 0, 0, 0
    finally:
        # Remove the temporary image file
        if temp_img_path and os.path.exists(temp_img_path):
            os.remove(temp_img_path)


# Function to process WAV file
def process_wav_file(wav_file, songs_dir, noise_calls_dir, bouts_csv_path, calls_csv_path, scanned_files, scanned_csv_path, processed_files):
    try:
        has_bouts, bboxes, spectrogram_length, data_length, fs = check_for_bouts(wav_file, temp_path)

        results = []
        for bbox in bboxes:
            x1, y1, x2, y2, conf, cls = bbox
            entry = {
                'wav_folder_path': os.path.dirname(wav_file),
                'wav_filename': os.path.basename(wav_file),
                'spectrogram_start_time': x1.item(),
                'spectrogram_end_time': x2.item(),
                'wav_file_start_time': (x1.item() / spectrogram_length) * (data_length / fs),
                'wav_file_end_time': (x2.item() / spectrogram_length) * (data_length / fs),
                'confidence': conf.item(),
                'label_class': cls.item(),
                'bbox_x1': x1.item(),
                'bbox_y1': y1.item(),
                'bbox_x2': x2.item(),
                'bbox_y2': y2.item()
            }
            results.append(entry)

        # Append results to CSV files
        if results:
            bouts_results = [entry for entry in results if entry['label_class'] == 0]
            calls_results = [entry for entry in results if entry['label_class'] == 1]

            with lock:
                if bouts_results:
                    append_to_csv(bouts_results, bouts_csv_path)
                if calls_results:
                    append_to_csv(calls_results, calls_csv_path)

        # Move the file based on detection results
        if has_bouts:
            shutil.move(wav_file, os.path.join(songs_dir, os.path.basename(wav_file)))
            with lock:
                processed_files.add(os.path.basename(wav_file))  # Thread-safe addition
            print(f"Moved {wav_file} to Songs")
        else:
            shutil.move(wav_file, os.path.join(noise_calls_dir, os.path.basename(wav_file)))
            print(f"Moved {wav_file} to Noise_Calls")

        # Update scanned files and save to CSV immediately
        with lock:
            scanned_files.append(os.path.basename(wav_file))
            pd.DataFrame({'filename': scanned_files}).to_csv(scanned_csv_path, index=False)

        return {
            'filepath': wav_file,
            'filename': os.path.basename(wav_file),
            'bboxes': bboxes,
            'spectrogram_length': spectrogram_length,
            'data_length': data_length,
            'fs': fs
        }
    except Exception as e:
        print(f"Error processing {wav_file}: {e}")
        return None

# Function to re-process WAV file that was missed in the original scan
def reprocess_wav_file(wav_file, noise_calls_dir, bouts_csv_path, calls_csv_path):
    try:
        has_bouts, bboxes, spectrogram_length, data_length, fs = check_for_bouts(wav_file, temp_path)

        results = []
        for bbox in bboxes:
            x1, y1, x2, y2, conf, cls = bbox
            entry = {
                'wav_folder_path': os.path.dirname(wav_file),
                'wav_filename': os.path.basename(wav_file),
                'spectrogram_start_time': x1.item(),
                'spectrogram_end_time': x2.item(),
                'wav_file_start_time': (x1.item() / spectrogram_length) * (data_length / fs),
                'wav_file_end_time': (x2.item() / spectrogram_length) * (data_length / fs),
                'confidence': conf.item(),
                'label_class': cls.item(),
                'bbox_x1': x1.item(),
                'bbox_y1': y1.item(),
                'bbox_x2': x2.item(),
                'bbox_y2': y2.item()
            }
            results.append(entry)

        # Append results to CSV files
        if results:
            bouts_results = [entry for entry in results if entry['label_class'] == 0]
            calls_results = [entry for entry in results if entry['label_class'] == 1]

            with lock:
                if bouts_results:
                    append_to_csv(bouts_results, bouts_csv_path)
                if calls_results:
                    append_to_csv(calls_results, calls_csv_path)

        if has_bouts:
            print(f"Reprocessed and found bouts in {wav_file}")
        else:
            print(f"Reprocessed {wav_file}, no bouts found")
            
            # Add this block to move files without bouts to the Noise_Calls folder
            shutil.move(wav_file, os.path.join(noise_calls_dir, os.path.basename(wav_file)))
            print(f"Moved {wav_file} to Noise_Calls after re-scan")

    except Exception as e:
        print(f"Error reprocessing {wav_file}: {e}")


# Function to append results to CSV
def append_to_csv(results, csv_path):
    # Define the expected columns
    columns = [
        'wav_folder_path', 'wav_filename', 'spectrogram_start_time', 'spectrogram_end_time',
        'wav_file_start_time', 'wav_file_end_time', 'confidence', 'label_class',
        'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2'
    ]
    
    # Convert results to DataFrame
    new_df = pd.DataFrame(results, columns=columns)
    
    # Append to the CSV file
    if os.path.exists(csv_path):
        new_df.to_csv(csv_path, mode='a', header=False, index=False)
    else:
        new_df.to_csv(csv_path, mode='w', header=True, index=False)

# Function to hash individual files to avoid duplicates
def hash_file(filepath):
    """Returns the MD5 hash of the file content."""
    hasher = hashlib.md5()
    with open(filepath, 'rb') as file:
        buf = file.read()
        hasher.update(buf)
    return hasher.hexdigest()

# Function to gather filename of wav files in folders and zip files
def get_all_wav_files(hatch_path, bird_path):
    wav_files = {}  # Use a dictionary to avoid duplicates by file content hash
    songs_dir = os.path.join(hatch_path, 'Songs')
    noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')

    # Extract ZIP files recursively
    zip_files = glob(os.path.join(hatch_path, '**', '*.zip'), recursive=True)
    for zip_file in zip_files:
        try:
            with zipfile.ZipFile(zip_file, 'r') as zip_ref:
                for file_info in zip_ref.infolist():
                    # Check if it's a .wav file
                    if file_info.filename.endswith('.wav'):
                        try:
                            # Test individual file for corruption
                            zip_ref.extract(file_info, hatch_path)
                        except Exception as e:
                            print(f"Skipping corrupted file {file_info.filename} in {zip_file}: {e}")
                            continue  # Skip corrupted file and continue with the next one
        except zipfile.BadZipFile:
            print(f"Skipping corrupted ZIP file: {zip_file}")
            continue  # Skip the corrupted ZIP and move on

        # Move the ZIP file to the birdname folder (at the same level as the mic folder)
        shutil.move(zip_file, os.path.join(bird_path, os.path.basename(zip_file)))

    # Function to add files based on their content hash
    def add_wav_files(dir_path):
        for wav_file in glob(os.path.join(dir_path, '**', '*.wav'), recursive=True):
            file_hash = hash_file(wav_file)
            if file_hash not in wav_files:
                wav_files[file_hash] = wav_file
    
    # Add WAV files from the main directory, Songs, and Noise_Calls
    add_wav_files(hatch_path)
    if os.path.exists(songs_dir):
        add_wav_files(songs_dir)
    if os.path.exists(noise_calls_dir):
        add_wav_files(noise_calls_dir)
    
    return list(wav_files.values())  # Return only the unique file paths

# Function to check if a file has already been scanned
def is_already_scanned(wav_file, scanned_files):
    return os.path.basename(wav_file) in scanned_files

# Function to check if a song file is in the bouts CSV
def is_in_bouts_csv(wav_file, bouts_csv_path):
    if os.path.exists(bouts_csv_path):
        try:
            bouts_df = pd.read_csv(bouts_csv_path)
            return os.path.basename(wav_file) in bouts_df['wav_filename'].values
        except pd.errors.EmptyDataError:
            return False
    return False
# Out:
# Using cache found in C:\Users\ucsfg/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-9-18 Python-3.12.8 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3050, 8192MiB)
#
# Fusing layers...
# Model summary: 166 layers, 7056607 parameters, 0 gradients
# Adding AutoShape...

# %%
# Manually set the selected birds for scanning
# You can list one bird or multiple birds here
# Example: selected_birds = ['bird01', 'bird03'] or selected_birds = ['bird01'] for one bird
# If you want to process all birds, you can set selected_birds = ['all']

# Base directory and suppression of warnings remain unchanged
# Dirs for analysis on miniscope. [D:/Birdsong_581E,D:/Birdsong_581D,Birdsong_591F,D:/Birdsong_560M]
base_dir = r'D:\Birdsong_581E'
warnings.filterwarnings("ignore", category=FutureWarning, message=".*torch.cuda.amp.autocast.*")

# List all available birds
available_birds = [bird for bird in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, bird))]

# Manually set the birds you want to process
selected_birds = ['R90', 'R93','R108','R158','R160','W35','W37','W40','W89','W92','Y27','Y40']
# selected_birds = available_birds  # Set to process all birds, or you can choose specific birds

# Main processing function for each bird
def process_bird(bird_name, base_dir):
    bird_path = os.path.join(base_dir, bird_name)
    mic_path = os.path.join(bird_path, 'mic')

    if not os.path.exists(mic_path):
        print(f"No 'mic' folder found for {bird_name}.")
        return

    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        bird_name = bird_name  # Corrected this to use bird_name from function
        hatch_day = hatch_folder    

        if not os.path.isdir(hatch_path):
            continue

        songs_dir = os.path.join(hatch_path, 'Songs')
        noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')

        # Create Songs and Noise_Calls directories if they don't exist
        os.makedirs(songs_dir, exist_ok=True)
        os.makedirs(noise_calls_dir, exist_ok=True)

        bouts_csv_path = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_day}.csv')
        calls_csv_path = os.path.join(hatch_path, f'results_calls_{bird_name}_{hatch_day}.csv')
        scanned_csv_path = os.path.join(hatch_path, f'wav_scanned_{bird_name}_{hatch_day}.csv')
        #print(f"Processing: {bouts_csv_path}")
        
        scanned_files = []
        if os.path.exists(scanned_csv_path):
            try:
                scanned_df = pd.read_csv(scanned_csv_path, on_bad_lines='skip')
                scanned_files = scanned_df['filename'].tolist()
            except pd.errors.EmptyDataError:
                scanned_files = []

        wav_files = get_all_wav_files(hatch_path, bird_path)

        # Filter out already scanned files
        unscanned_wav_files = [wav_file for wav_file in wav_files if not is_already_scanned(wav_file, scanned_files)]

        processed_files = set()  # Thread-safe modification

        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = {executor.submit(process_wav_file, wav_file, songs_dir, noise_calls_dir, bouts_csv_path, calls_csv_path, scanned_files, scanned_csv_path, processed_files): wav_file for wav_file in unscanned_wav_files}
            for i, future in enumerate(tqdm(concurrent.futures.as_completed(futures), total=len(unscanned_wav_files), desc="Processing WAV files")):
                if i % 10 == 0:
                    clear_output(wait=True)  # Clear the output every 10 files
                wav_file = futures[future]
                try:
                    result = future.result()
                except Exception as exc:
                    print(f'{wav_file} generated an exception: {exc}')

        # Final check: Ensure all files in Songs appear in both wav_scanned.csv and results_bouts.csv
        song_files_to_rescan = []
        for song_file in glob(os.path.join(songs_dir, '*.wav')):
            if not is_already_scanned(song_file, scanned_files):
                print(f"Appending {song_file} to scanned files")
                with lock:
                    scanned_files.append(os.path.basename(song_file))
                    pd.DataFrame({'filename': scanned_files}).to_csv(scanned_csv_path, index=False)
            if not is_in_bouts_csv(song_file, bouts_csv_path):
                print(f"File {song_file} missing from results_bouts.csv, adding to re-scan list")
                song_files_to_rescan.append(song_file)

        # Parallel processing for the re-scan of song files
        with concurrent.futures.ThreadPoolExecutor() as reprocess_executor:
            reprocess_futures = {reprocess_executor.submit(reprocess_wav_file, song_file, noise_calls_dir, bouts_csv_path, calls_csv_path): song_file for song_file in song_files_to_rescan}
            for i, future in enumerate(tqdm(concurrent.futures.as_completed(reprocess_futures), total=len(song_files_to_rescan), desc="Re-scanning Songs")):
                if i % 10 == 0:
                    clear_output(wait=True)  # Clear the output every 10 iterations
                song_file = reprocess_futures[future]
                try:
                    future.result()
                except Exception as exc:
                    print(f'{song_file} generated an exception during re-scan: {exc}')


# Process the selected birds
if selected_birds:
    for bird in selected_birds:
        print(bird)
        process_bird(bird, base_dir)
else:
    print("No birds selected. Exiting...")
# Out:
# Processing WAV files:  71%|███████▏  | 1412/1981 [3:10:27<1:25:17,  8.99s/it]
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50378226_3_21_13_59_38.wav to Noise_Calls
# Processing WAV files:  71%|███████▏  | 1412/1981 [3:11:02<1:16:58,  8.12s/it]
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50473452_3_21_14_1_13.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50314736_3_21_13_58_34.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5038927_3_21_1_23_58.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50346484_3_21_13_59_6.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50441722_3_21_14_0_41.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50505198_3_21_14_1_45.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50536922_3_21_14_2_16.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50759124_3_21_14_5_59.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50568664_3_21_14_2_48.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50600380_3_21_14_3_20.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50663889_3_21_14_4_23.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50632132_3_21_14_3_52.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5070652_3_21_1_24_30.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50854380_3_21_14_7_34.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50695644_3_21_14_4_55.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50949581_3_21_14_9_9.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50790882_3_21_14_6_30.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50822622_3_21_14_7_2.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50727401_3_21_14_5_27.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50886106_3_21_14_8_6.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50917846_3_21_14_8_37.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.50981298_3_21_14_9_41.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51171747_3_21_14_12_51.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51044770_3_21_14_10_44.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51108256_3_21_14_11_48.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51140012_3_21_14_12_20.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51203486_3_21_14_13_23.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51266973_3_21_14_14_26.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51013018_3_21_14_10_13.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51235215_3_21_14_13_55.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51076507_3_21_14_11_16.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51393934_3_21_14_16_33.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5102399_3_21_1_25_2.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51457393_3_21_14_17_37.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51425677_3_21_14_17_5.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51520843_3_21_14_18_40.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5134140_3_21_1_25_34.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51298702_3_21_14_14_58.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51362188_3_21_14_16_2.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51552576_3_21_14_19_12.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51489111_3_21_14_18_9.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51330436_3_21_14_15_30.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51616048_3_21_14_20_16.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51584328_3_21_14_19_44.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51679516_3_21_14_21_19.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51742975_3_21_14_22_22.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51711235_3_21_14_21_51.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5165891_3_21_1_26_5.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51869842_3_21_14_24_29.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51647788_3_21_14_20_47.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51774663_3_21_14_22_54.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52028441_3_21_14_27_8.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51933268_3_21_14_25_33.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52123601_3_21_14_28_43.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51901540_3_21_14_25_1.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51838108_3_21_14_23_58.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51964984_3_21_14_26_4.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52060170_3_21_14_27_40.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52155340_3_21_14_29_15.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51996730_3_21_14_26_36.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.51806393_3_21_14_23_26.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5197628_3_21_1_26_37.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52091881_3_21_14_28_11.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52218756_3_21_14_30_18.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52282222_3_21_14_31_22.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5229338_3_21_1_27_9.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52187053_3_21_14_29_47.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52409127_3_21_14_33_29.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52250489_3_21_14_30_50.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52472577_3_21_14_34_32.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52313957_3_21_14_31_53.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52504271_3_21_14_35_4.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52345693_3_21_14_32_25.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52662850_3_21_14_37_42.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52377402_3_21_14_32_57.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52440855_3_21_14_34_0.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52599428_3_21_14_36_39.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52567709_3_21_14_36_7.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5261093_3_21_1_27_41.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52535967_3_21_14_35_35.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52694566_3_21_14_38_14.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52631138_3_21_14_37_11.wav to Noise_Calls
# WARNING  NMS time limit 0.550s exceeded
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52789735_3_21_14_39_49.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52916693_3_21_14_41_56.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52884986_3_21_14_41_24.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52726281_3_21_14_38_46.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52758008_3_21_14_39_18.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52948405_3_21_14_42_28.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52853229_3_21_14_40_53.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52821487_3_21_14_40_21.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53202195_3_21_14_46_42.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53075263_3_21_14_44_35.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53043548_3_21_14_44_3.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.52980131_3_21_14_43_0.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53233909_3_21_14_47_13.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53138746_3_21_14_45_38.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53011825_3_21_14_43_31.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53170487_3_21_14_46_10.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53106977_3_21_14_45_6.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53265636_3_21_14_47_45.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.532987_3_21_0_8_52.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5324561_3_21_1_28_44.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5292839_3_21_1_28_12.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53297355_3_21_14_48_17.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53360794_3_21_14_49_20.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53455968_3_21_14_50_55.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53392515_3_21_14_49_52.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53329066_3_21_14_48_49.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53424238_3_21_14_50_24.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53519416_3_21_14_51_59.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53551147_3_21_14_52_31.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5356271_3_21_1_29_16.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53487666_3_21_14_51_27.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53646261_3_21_14_54_6.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53614552_3_21_14_53_34.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53582844_3_21_14_53_2.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53899965_3_21_14_58_19.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53677937_3_21_14_54_37.wav to Songs
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53741369_3_21_14_55_41.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53931690_3_21_14_58_51.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53709665_3_21_14_55_9.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53804793_3_21_14_56_44.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53773090_3_21_14_56_13.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54122063_3_21_15_2_2.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53963404_3_21_14_59_23.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53995136_3_21_14_59_55.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54058587_3_21_15_0_58.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5388034_3_21_1_29_48.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53836505_3_21_14_57_16.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.5419766_3_21_1_30_19.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54248931_3_21_15_4_8.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54026856_3_21_15_0_26.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.53868242_3_21_14_57_48.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54090338_3_21_15_1_30.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54375908_3_21_15_6_15.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54217218_3_21_15_3_37.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54153771_3_21_15_2_33.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54185489_3_21_15_3_5.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54312409_3_21_15_5_12.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54407578_3_21_15_6_47.wav to Noise_Calls
# Moved D:\Birdsong_581E\R90\mic\445\R90_45737.54280682_3_21_15_4_40.wav to Noise_Calls

# %% [markdown]
# # Remove noise and call wav files which have the least amount of calls
#
# This script processes bird song recordings to manage and retain the top 100 WAV files with the most calls in each hatch day folder. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `pandas`, and `glob`.
#
# 2. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 3. **Define Function**:
#     - `process_hatch_day_folder`: This function processes each hatch day folder by:
#         - Checking if the `results_calls.csv` file exists.
#         - Loading the CSV file and counting the number of calls in each WAV file.
#         - Sorting the files by call count and retaining the top 100.
#         - Deleting the remaining files in the `Noise_Calls` folder.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it calls the `process_hatch_day_folder` function to manage the WAV files based on the number of calls.
#
# This script helps in organizing and retaining the most relevant bird song recordings for further analysis.

# %%
import os
import csv
import pandas as pd
from glob import glob


# Function to process each hatch day folder
def process_hatch_day_folder(hatch_path, bird_name, hatch_day):
    calls_csv_path = os.path.join(hatch_path, f'results_calls_{bird_name}_{hatch_day}.csv')
    noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')
    
    # Check if the calls CSV file exists
    if not os.path.exists(calls_csv_path):
        print(f"No CSV file found for {hatch_path}. Skipping...")
        return
    
    try:
        # Load the calls CSV file
        calls_df = pd.read_csv(calls_csv_path, on_bad_lines='skip')
        
        if calls_df.empty:
            print(f"No data in {calls_csv_path}. Skipping...")
            return
        
        # Group by filename and count the number of calls
        call_counts = calls_df.groupby('wav_filename').size().reset_index(name='call_count')
        
        # Sort by call count in descending order and keep the top 100
        top_calls = call_counts.sort_values(by='call_count', ascending=False).head(100)
        
        # Get the list of top 100 filenames
        top_filenames = top_calls['wav_filename'].tolist()
        
        # Get all WAV files in the Noise_Calls folder
        all_wav_files = glob(os.path.join(noise_calls_dir, '*.wav'))
        
        # Delete files not in the top 100
        for wav_file in all_wav_files:
            if os.path.basename(wav_file) not in top_filenames:
                os.remove(wav_file)
                print(f"Deleted {wav_file}")
    except pd.errors.EmptyDataError:
        print(f"EmptyDataError: No columns to parse from file {calls_csv_path}")

# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        
        if not os.path.isdir(hatch_path):
            continue
        
        bird_name = bird_dir
        hatch_day = hatch_folder
        
        process_hatch_day_folder(hatch_path, bird_name, hatch_day)


def align_csv_columns(file_path, expected_columns=12):
    aligned_rows = []
    
    try:
        with open(file_path, 'r') as infile:
            reader = csv.reader(infile)
            for row in reader:
                # Count non-empty cells
                non_empty_cells = [cell for cell in row if cell]
                
                if len(non_empty_cells) == expected_columns:
                    # Shift the row to start at column 1 and ensure it has exactly 12 columns
                    aligned_row = non_empty_cells[:expected_columns]
                else:
                    aligned_row = row
                
                # Ensure the row has exactly 12 columns
                aligned_row = aligned_row[:expected_columns]
                
                aligned_rows.append(aligned_row)
        
        with open(file_path, 'w', newline='') as outfile:
            writer = csv.writer(outfile)
            writer.writerows(aligned_rows)
        print(f"CSV columns aligned successfully for {file_path}.")
    
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")

def process_hatch_folders(base_path, expected_columns=12):
    for root, dirs, files in os.walk(base_path):
        for file in files:
            if file.startswith('results_bout') or file.startswith('results_call'):
                file_path = os.path.join(root, file)
                align_csv_columns(file_path, expected_columns)

# Fix excel files
process_hatch_folders(base_dir)
# Out:
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.27618322_6_10_7_40_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.27883707_6_10_7_44_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28049639_6_10_7_47_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28100240_6_10_7_48_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28489708_6_10_7_54_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28553171_6_10_7_55_53.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28584880_6_10_7_56_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28648114_6_10_7_57_28.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28679915_6_10_7_57_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28711602_6_10_7_58_31.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28743141_6_10_7_59_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28774733_6_10_7_59_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28806333_6_10_8_0_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28841220_6_10_8_0_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28869939_6_10_8_1_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28900534_6_10_8_1_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.28942389_6_10_8_2_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29132065_6_10_8_5_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29156034_6_10_8_5_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29187688_6_10_8_6_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29262354_6_10_8_7_42.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29325860_6_10_8_8_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29357332_6_10_8_9_17.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29365764_6_10_8_9_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29391644_6_10_8_9_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29402034_6_10_8_10_2.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29464135_6_10_8_11_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29473470_6_10_8_11_13.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29568319_6_10_8_12_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29598140_6_10_8_13_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29610395_6_10_8_13_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29644818_6_10_8_14_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29670612_6_10_8_14_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29702765_6_10_8_15_2.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29727340_6_10_8_15_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29740987_6_10_8_15_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29804345_6_10_8_16_44.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.29992792_6_10_8_19_52.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.30111326_6_10_8_21_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.30237708_6_10_8_23_57.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.30470816_6_10_8_27_50.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.30569635_6_10_8_29_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.30654196_6_10_8_30_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.30749575_6_10_8_32_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.30789464_6_10_8_33_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.30821147_6_10_8_33_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31035452_6_10_8_37_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31130596_6_10_8_38_50.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31192098_6_10_8_39_52.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31260864_6_10_8_41_0.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31365443_6_10_8_42_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31431270_6_10_8_43_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31476209_6_10_8_44_36.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31494738_6_10_8_44_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31520174_6_10_8_45_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31538018_6_10_8_45_38.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31554572_6_10_8_45_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31564629_6_10_8_46_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31673115_6_10_8_47_53.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31705294_6_10_8_48_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31744607_6_10_8_49_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31783468_6_10_8_49_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31791660_6_10_8_49_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31834774_6_10_8_50_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31840769_6_10_8_50_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31854179_6_10_8_50_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31885332_6_10_8_51_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31916963_6_10_8_51_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31938726_6_10_8_52_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31978708_6_10_8_52_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.31990511_6_10_8_53_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32053900_6_10_8_54_13.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32118908_6_10_8_55_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32170466_6_10_8_56_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32229555_6_10_8_57_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32243423_6_10_8_57_23.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32320335_6_10_8_58_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32349422_6_10_8_59_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32359839_6_10_8_59_19.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32367731_6_10_8_59_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32399366_6_10_8_59_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32430978_6_10_9_0_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32451118_6_10_9_0_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32476053_6_10_9_1_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32509487_6_10_9_1_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32521544_6_10_9_2_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32576472_6_10_9_2_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32587798_6_10_9_3_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32604849_6_10_9_3_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32638300_6_10_9_3_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32669985_6_10_9_4_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32725714_6_10_9_5_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32792103_6_10_9_6_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32801904_6_10_9_6_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32822321_6_10_9_7_2.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32846066_6_10_9_7_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32877650_6_10_9_7_57.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32889211_6_10_9_8_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32896507_6_10_9_8_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.32995846_6_10_9_9_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33027443_6_10_9_10_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33089169_6_10_9_11_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33424058_6_10_9_17_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33442276_6_10_9_17_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33471183_6_10_9_17_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33604515_6_10_9_20_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33664262_6_10_9_21_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33739965_6_10_9_22_19.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33766997_6_10_9_22_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33899789_6_10_9_24_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33920873_6_10_9_25_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.33961904_6_10_9_26_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34000079_6_10_9_26_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34056564_6_10_9_27_36.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34224915_6_10_9_30_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34256799_6_10_9_30_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34332591_6_10_9_32_12.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34401189_6_10_9_33_21.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34426383_6_10_9_33_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34434974_6_10_9_33_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34487704_6_10_9_34_47.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34519302_6_10_9_35_19.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34582497_6_10_9_36_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34614789_6_10_9_36_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34676029_6_10_9_37_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34717503_6_10_9_38_37.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34743053_6_10_9_39_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34749070_6_10_9_39_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34849029_6_10_9_40_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34880916_6_10_9_41_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.34945839_6_10_9_42_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35014926_6_10_9_43_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35157647_6_10_9_45_57.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35383050_6_10_9_49_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35563222_6_10_9_52_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35594776_6_10_9_53_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35635698_6_10_9_53_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35656875_6_10_9_54_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35688461_6_10_9_54_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35699519_6_10_9_54_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35759961_6_10_9_55_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35781382_6_10_9_56_21.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35788133_6_10_9_56_28.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35803574_6_10_9_56_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35829721_6_10_9_57_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35836768_6_10_9_57_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35868741_6_10_9_57_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35899118_6_10_9_58_19.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35926004_6_10_9_58_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35940135_6_10_9_59_0.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35965112_6_10_9_59_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.35995530_6_10_9_59_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.36289037_6_10_10_4_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.36297862_6_10_10_4_57.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.36986037_6_10_10_16_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.37036007_6_10_10_17_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.37055542_6_10_10_17_35.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.37068058_6_10_10_17_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.37861988_6_10_10_31_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.37895967_6_10_10_31_35.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.38395183_6_10_10_39_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.38426489_6_10_10_40_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.38560501_6_10_10_42_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.38592611_6_10_10_43_12.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.38919438_6_10_10_48_39.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.39733250_6_10_11_2_13.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.39926116_6_10_11_5_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.40392738_6_10_11_13_12.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.40411257_6_10_11_13_31.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.40431857_6_10_11_13_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.40583479_6_10_11_16_23.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.40859374_6_10_11_20_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.40982320_6_10_11_23_2.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41122840_6_10_11_25_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41334269_6_10_11_28_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41358311_6_10_11_29_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41391058_6_10_11_29_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41515284_6_10_11_31_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41529986_6_10_11_32_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41618511_6_10_11_33_38.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41640216_6_10_11_34_0.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41693479_6_10_11_34_53.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41702561_6_10_11_35_2.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41727465_6_10_11_35_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41796716_6_10_11_36_36.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.41820584_6_10_11_37_0.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42221586_6_10_11_43_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42229884_6_10_11_43_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42261589_6_10_11_44_21.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42293954_6_10_11_44_53.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42341010_6_10_11_45_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42360422_6_10_11_46_0.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42463191_6_10_11_47_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42471475_6_10_11_47_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42491548_6_10_11_48_11.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42539378_6_10_11_48_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42759779_6_10_11_52_39.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42766338_6_10_11_52_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42920447_6_10_11_55_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.42952060_6_10_11_55_52.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43014145_6_10_11_56_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43023722_6_10_11_57_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43098614_6_10_11_58_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43121499_6_10_11_58_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43274198_6_10_12_1_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43327778_6_10_12_2_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43365862_6_10_12_2_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43384341_6_10_12_3_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43462736_6_10_12_4_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43511269_6_10_12_5_11.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43559950_6_10_12_5_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43592299_6_10_12_6_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43605722_6_10_12_6_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43628180_6_10_12_7_8.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43692444_6_10_12_8_12.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43710223_6_10_12_8_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43769541_6_10_12_9_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43801485_6_10_12_10_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43834715_6_10_12_10_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43868664_6_10_12_11_8.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43905961_6_10_12_11_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43929173_6_10_12_12_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.43983040_6_10_12_13_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44006282_6_10_12_13_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44382882_6_10_12_19_42.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44406769_6_10_12_20_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44438435_6_10_12_20_38.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44519355_6_10_12_21_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44534308_6_10_12_22_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44567923_6_10_12_22_47.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44595272_6_10_12_23_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44642588_6_10_12_24_2.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.44679119_6_10_12_24_39.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45019382_6_10_12_30_19.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45127027_6_10_12_32_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45271995_6_10_12_34_31.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45303584_6_10_12_35_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45367556_6_10_12_36_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45389145_6_10_12_36_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45397019_6_10_12_36_37.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45425619_6_10_12_37_5.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45438792_6_10_12_37_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45446160_6_10_12_37_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45464261_6_10_12_37_44.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45502822_6_10_12_38_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45569019_6_10_12_39_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45582031_6_10_12_39_42.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45599434_6_10_12_39_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45732617_6_10_12_42_12.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45778980_6_10_12_42_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45875913_6_10_12_44_35.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45906799_6_10_12_45_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45926125_6_10_12_45_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.45955994_6_10_12_45_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46040981_6_10_12_47_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46073112_6_10_12_47_53.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46123082_6_10_12_48_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46150288_6_10_12_49_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46215932_6_10_12_50_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46221986_6_10_12_50_21.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46288149_6_10_12_51_28.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46447083_6_10_12_54_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46701431_6_10_12_58_21.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46797786_6_10_12_59_57.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.46882945_6_10_13_1_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47016017_6_10_13_3_36.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47064122_6_10_13_4_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47117727_6_10_13_5_17.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47162270_6_10_13_6_2.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47209674_6_10_13_6_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47252549_6_10_13_7_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47341800_6_10_13_9_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47415442_6_10_13_10_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47422314_6_10_13_10_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47455455_6_10_13_10_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47471942_6_10_13_11_11.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47500158_6_10_13_11_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47515852_6_10_13_11_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47553052_6_10_13_12_33.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47597217_6_10_13_13_17.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47619341_6_10_13_13_39.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47628690_6_10_13_13_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47714240_6_10_13_15_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47879167_6_10_13_17_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47905667_6_10_13_18_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47937297_6_10_13_18_57.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.47969033_6_10_13_19_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48032301_6_10_13_20_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48126850_6_10_13_22_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48237218_6_10_13_23_57.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48324506_6_10_13_25_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48467711_6_10_13_27_47.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48606966_6_10_13_30_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48663672_6_10_13_31_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48858891_6_10_13_34_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48870300_6_10_13_34_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48891395_6_10_13_34_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.48923587_6_10_13_35_23.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49061772_6_10_13_37_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49156913_6_10_13_39_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49172759_6_10_13_39_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49284559_6_10_13_41_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49389011_6_10_13_43_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49441726_6_10_13_44_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49506022_6_10_13_45_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49558676_6_10_13_45_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49581443_6_10_13_46_21.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49613183_6_10_13_46_53.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49645314_6_10_13_47_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49665594_6_10_13_47_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49690819_6_10_13_48_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49705491_6_10_13_48_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49727705_6_10_13_48_47.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49756238_6_10_13_49_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49807013_6_10_13_50_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49822770_6_10_13_50_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49854626_6_10_13_50_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49886621_6_10_13_51_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49936032_6_10_13_52_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49950080_6_10_13_52_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.49999384_6_10_13_53_19.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50019193_6_10_13_53_39.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50096866_6_10_13_54_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50223513_6_10_13_57_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50273518_6_10_13_57_53.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50492942_6_10_14_1_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50506102_6_10_14_1_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50597120_6_10_14_3_17.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50723428_6_10_14_5_23.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50755025_6_10_14_5_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50793050_6_10_14_6_33.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50904300_6_10_14_8_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50956950_6_10_14_9_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.50988899_6_10_14_9_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51014729_6_10_14_10_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51042085_6_10_14_10_42.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51059148_6_10_14_10_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51093982_6_10_14_11_33.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51280809_6_10_14_14_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51344173_6_10_14_15_44.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51358437_6_10_14_15_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51415340_6_10_14_16_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51511256_6_10_14_18_31.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51559730_6_10_14_19_19.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51578934_6_10_14_19_38.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51592789_6_10_14_19_52.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51614979_6_10_14_20_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51634229_6_10_14_20_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51649261_6_10_14_20_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51656154_6_10_14_20_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51665163_6_10_14_21_5.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51681645_6_10_14_21_21.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51758975_6_10_14_22_38.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51821520_6_10_14_23_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51839260_6_10_14_23_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51860459_6_10_14_24_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51892707_6_10_14_24_52.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.51987651_6_10_14_26_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52054925_6_10_14_27_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52105089_6_10_14_28_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52127379_6_10_14_28_47.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52330661_6_10_14_32_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52495400_6_10_14_34_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52527072_6_10_14_35_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52568934_6_10_14_36_8.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52576398_6_10_14_36_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52615054_6_10_14_36_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52630989_6_10_14_37_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52675254_6_10_14_37_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52686620_6_10_14_38_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52718253_6_10_14_38_38.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52766912_6_10_14_39_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52836095_6_10_14_40_36.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52904489_6_10_14_41_44.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.52985366_6_10_14_43_5.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53050132_6_10_14_44_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53081747_6_10_14_44_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53113346_6_10_14_45_13.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53164581_6_10_14_46_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53257766_6_10_14_47_37.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53300619_6_10_14_48_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53332850_6_10_14_48_52.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53340501_6_10_14_49_0.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53348673_6_10_14_49_8.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53501001_6_10_14_51_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53524012_6_10_14_52_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53603369_6_10_14_53_23.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53908808_6_10_14_58_28.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.53921131_6_10_14_58_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54135780_6_10_15_2_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54187521_6_10_15_3_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54244219_6_10_15_4_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54277217_6_10_15_4_37.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54285478_6_10_15_4_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54326910_6_10_15_5_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54339690_6_10_15_5_39.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54354558_6_10_15_5_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54375775_6_10_15_6_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54544055_6_10_15_9_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54693283_6_10_15_11_33.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.54726666_6_10_15_12_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.55026714_6_10_15_17_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.55035825_6_10_15_17_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.55305741_6_10_15_21_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.55541726_6_10_15_25_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.55555492_6_10_15_25_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.55618131_6_10_15_26_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.55660460_6_10_15_27_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.55996175_6_10_15_33_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56108895_6_10_15_35_8.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56189222_6_10_15_36_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56236869_6_10_15_37_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56327413_6_10_15_38_47.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56345566_6_10_15_39_5.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56356775_6_10_15_39_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56375002_6_10_15_39_35.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56406713_6_10_15_40_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56596427_6_10_15_43_16.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56607348_6_10_15_43_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.56803196_6_10_15_46_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57000928_6_10_15_50_0.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57025564_6_10_15_50_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57060445_6_10_15_51_0.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57075111_6_10_15_51_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57106747_6_10_15_51_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57184275_6_10_15_53_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57226095_6_10_15_53_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57444802_6_10_15_57_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57489855_6_10_15_58_9.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57508361_6_10_15_58_28.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57522758_6_10_15_58_42.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57554526_6_10_15_59_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57586141_6_10_15_59_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57607831_6_10_16_0_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57618239_6_10_16_0_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57655293_6_10_16_0_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57701480_6_10_16_1_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57786570_6_10_16_3_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57803517_6_10_16_3_23.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57824090_6_10_16_3_44.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.57863923_6_10_16_4_23.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58049977_6_10_16_7_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58392386_6_10_16_13_12.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58419578_6_10_16_13_39.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58464988_6_10_16_14_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58611194_6_10_16_16_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58668492_6_10_16_17_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58723331_6_10_16_18_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58772068_6_10_16_19_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58836071_6_10_16_20_36.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58858665_6_10_16_20_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58890318_6_10_16_21_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58908503_6_10_16_21_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.58940543_6_10_16_22_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59082222_6_10_16_24_42.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59173852_6_10_16_26_13.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59237304_6_10_16_27_17.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59269006_6_10_16_27_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59302424_6_10_16_28_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59383769_6_10_16_29_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59415399_6_10_16_30_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59511076_6_10_16_31_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59775209_6_10_16_36_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59794194_6_10_16_36_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59811298_6_10_16_36_51.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59824004_6_10_16_37_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59916141_6_10_16_38_36.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59935481_6_10_16_38_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59946116_6_10_16_39_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.59977980_6_10_16_39_37.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60074179_6_10_16_41_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60168660_6_10_16_42_48.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60178284_6_10_16_42_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60207668_6_10_16_43_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60250532_6_10_16_44_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60303982_6_10_16_45_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60454694_6_10_16_47_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60613179_6_10_16_50_13.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60635569_6_10_16_50_35.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60655966_6_10_16_50_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60687596_6_10_16_51_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60760676_6_10_16_52_40.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60792392_6_10_16_53_12.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60832203_6_10_16_53_52.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60875028_6_10_16_54_35.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60908358_6_10_16_55_8.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.60963448_6_10_16_56_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61026787_6_10_16_57_6.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61261410_6_10_17_1_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61271085_6_10_17_1_11.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61278800_6_10_17_1_18.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61305955_6_10_17_1_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61314869_6_10_17_1_54.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61403225_6_10_17_3_23.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61412746_6_10_17_3_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61444010_6_10_17_4_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61451245_6_10_17_4_11.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61514175_6_10_17_5_14.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61534860_6_10_17_5_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61580788_6_10_17_6_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61630338_6_10_17_7_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61641298_6_10_17_7_21.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61647487_6_10_17_7_27.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61704050_6_10_17_8_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61712721_6_10_17_8_32.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61744534_6_10_17_9_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61801485_6_10_17_10_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61825016_6_10_17_10_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.61969276_6_10_17_12_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62010627_6_10_17_13_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62041146_6_10_17_14_1.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62112762_6_10_17_15_12.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62128143_6_10_17_15_28.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62156033_6_10_17_15_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62205051_6_10_17_16_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62353491_6_10_17_19_13.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62362279_6_10_17_19_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62403433_6_10_17_20_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62464675_6_10_17_21_4.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62516812_6_10_17_21_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62703654_6_10_17_25_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62816133_6_10_17_26_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62828308_6_10_17_27_8.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62917407_6_10_17_28_37.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.62943575_6_10_17_29_3.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63140534_6_10_17_32_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63204675_6_10_17_33_24.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63214564_6_10_17_33_34.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63236628_6_10_17_33_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63269277_6_10_17_34_29.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63283607_6_10_17_34_43.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63469247_6_10_17_37_49.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63500914_6_10_17_38_20.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63526476_6_10_17_38_46.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63535757_6_10_17_38_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63579773_6_10_17_39_39.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63598443_6_10_17_39_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63630335_6_10_17_40_30.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63662087_6_10_17_41_2.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63885684_6_10_17_44_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.63910475_6_10_17_45_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64070545_6_10_17_47_50.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64315985_6_10_17_51_55.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64348162_6_10_17_52_28.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64455679_6_10_17_54_15.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64485166_6_10_17_54_45.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64496727_6_10_17_54_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64533666_6_10_17_55_33.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64559348_6_10_17_55_59.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64570077_6_10_17_56_10.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64582795_6_10_17_56_22.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64604553_6_10_17_56_44.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64616230_6_10_17_56_56.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64655037_6_10_17_57_35.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64687004_6_10_17_58_7.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64706668_6_10_17_58_26.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64716671_6_10_17_58_36.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64853703_6_10_18_0_53.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64885536_6_10_18_1_25.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64961202_6_10_18_2_41.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64978899_6_10_18_2_58.wav
# Deleted D:\Birdsong_581E\R07\mic\161\Noise_Calls\R07_45453.64994024_6_10_18_3_14.wav
# ...
# No CSV file found for D:\Birdsong_581E\W37\mic\3-19-25. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\428. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\443. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\444. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\445. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\446. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\447. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\448. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\449. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\452. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\453. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\454. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\455. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\456. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\457. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\458. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\459. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\460. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\461. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\462. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\463. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\464. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\466. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\467. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\468. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\469. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\470. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\471. Skipping...
# No CSV file found for D:\Birdsong_581E\W37\mic\472. Skipping...
# No CSV file found for D:\Birdsong_581E\W40\mic\222. Skipping...
# No CSV file found for D:\Birdsong_581E\W40\mic\224. Skipping...
# No CSV file found for D:\Birdsong_581E\W40\mic\240. Skipping...
# No CSV file found for D:\Birdsong_581E\W40\mic\242. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\154. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\155. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\156. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\157. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\158. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\159. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\160. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\161. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\162. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\163. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\164. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\165. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\166. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\167. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\168. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\169. Skipping...
# No CSV file found for D:\Birdsong_581E\W89\mic\170. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\443. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\444. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\445. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\446. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\447. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\448. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\449. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\452. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\453. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\454. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\455. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\456. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\457. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\458. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\459. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\460. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\461. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\462. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\463. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\466. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\467. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\468. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\469. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\470. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\471. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\472. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\473. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\474. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\475. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\476. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\477. Skipping...
# No CSV file found for D:\Birdsong_581E\W92\mic\478. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\250. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\251. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\252. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\253. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\254. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\255. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\256. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\257. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\258. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\259. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\260. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\261. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\263. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\264. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\265. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\266. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\267. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\268. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\269. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\270. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\271. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\272. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\273. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\274. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\275. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\276. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\277. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\278. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\279. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\280. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\281. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\282. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\283. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\284. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\285. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\286. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\287. Skipping...
# No CSV file found for D:\Birdsong_581E\Y27\mic\291. Skipping...
# No CSV file found for D:\Birdsong_581E\Y40\mic\494. Skipping...
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\161\results_bouts_R07_161.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\161\results_calls_R07_161.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\162\results_bouts_R07_162.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\162\results_calls_R07_162.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\163\results_bouts_R07_163.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\163\results_calls_R07_163.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\164\results_bouts_R07_164.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\166\results_bouts_R07_166.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\168\results_bouts_R07_168.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\168\results_calls_R07_168.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\170\results_bouts_R07_170.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\170\results_calls_R07_170.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\171\results_bouts_R07_171.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\171\results_calls_R07_171.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\177\results_bouts_R07_177.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\177\results_calls_R07_177.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\478\results_bouts_R07_478.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\478\results_calls_R07_478.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\479\results_bouts_R07_479.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R07\mic\479\results_calls_R07_479.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\478\results_bouts_R108_478.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\478\results_calls_R108_478.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\479\results_bouts_R108_479.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\479\results_calls_R108_479.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\480\results_bouts_R108_480.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\480\results_calls_R108_480.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\481\results_bouts_R108_481.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\481\results_calls_R108_481.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\482\results_bouts_R108_482.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\482\results_calls_R108_482.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\483\results_bouts_R108_483.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\483\results_calls_R108_483.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\484\results_bouts_R108_484.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\484\results_calls_R108_484.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\485\results_bouts_R108_485.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\485\results_calls_R108_485.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\486\results_bouts_R108_486.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\486\results_calls_R108_486.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\487\results_bouts_R108_487.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\487\results_calls_R108_487.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\488\results_bouts_R108_488.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\488\results_calls_R108_488.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\489\results_bouts_R108_489.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\489\results_calls_R108_489.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\490\results_bouts_R108_490.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\490\results_calls_R108_490.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\491\results_bouts_R108_491.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\491\results_calls_R108_491.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\492\results_bouts_R108_492.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\492\results_calls_R108_492.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\493\results_bouts_R108_493.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\493\results_calls_R108_493.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\494\results_bouts_R108_494.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R108\mic\494\results_calls_R108_494.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R158\mic\494\results_bouts_R158_494.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R158\mic\494\results_calls_R158_494.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\276\results_bouts_R160_276.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\276\results_calls_R160_276.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\277\results_bouts_R160_277.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\277\results_calls_R160_277.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\278\results_bouts_R160_278.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\278\results_calls_R160_278.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\279\results_bouts_R160_279.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\279\results_calls_R160_279.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\280\results_bouts_R160_280.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R160\mic\280\results_calls_R160_280.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\0\results_bouts_R23_hatchlings_0.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\0\results_calls_R23_hatchlings_0.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\1\results_bouts_R23_hatchlings_1.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\1\results_calls_R23_hatchlings_1.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\10\results_bouts_R23_hatchlings_10.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\10\results_calls_R23_hatchlings_10.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\11\results_bouts_R23_hatchlings_11.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\11\results_calls_R23_hatchlings_11.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\2\results_bouts_R23_hatchlings_2.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\2\results_calls_R23_hatchlings_2.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\3\results_bouts_R23_hatchlings_3.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\3\results_calls_R23_hatchlings_3.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\4\results_bouts_R23_hatchlings_4.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\4\results_calls_R23_hatchlings_4.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\5\results_bouts_R23_hatchlings_5.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\5\results_calls_R23_hatchlings_5.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\6\results_bouts_R23_hatchlings_6.csv.
# CSV columns aligned successfully for D:\Birdsong_581E\R23_hatchlings\mic\6\results_calls_R23_hatchlings_6.csv.

# %% [markdown]
# # Simple bout analytics
#
# This script processes bird song recordings to generate and save plots for the distribution of bout durations and YOLO confidence scores. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `pandas`, `matplotlib.pyplot`, and `os`.
#
# 2. **Define Functions**:
#     - `plot_bout_durations`: This function calculates and plots the distribution of bout durations from the `results_bouts.csv` file. It saves the plot as an SVG file.
#     - `plot_yolo_confidence`: This function calculates and plots the distribution of YOLO confidence scores from the `results_bouts.csv` and `results_calls.csv` files. It saves the plot as an SVG file.
#
# 3. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories.
#     - It loads the results from `results_bouts.csv` and `results_calls.csv` if available.
#     - It calls the `plot_bout_durations` and `plot_yolo_confidence` functions to generate and save the plots.
#
# 5. **Output**: The script prints a message indicating that the plots have been generated and saved successfully.
#
# This script helps in visualizing the distribution of bout durations and YOLO confidence scores for bird song recordings.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os


# Function to plot and save the distribution of bout durations
def plot_bout_durations(hatch_path, bird_name, hatch_number):
    bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_number}.csv')
    if os.path.exists(bouts_file):
        try:
            bouts_df = pd.read_csv(bouts_file)
            if bouts_df.empty:
                print(f"No data in {bouts_file}")
                return
            bouts_df['duration'] = bouts_df['wav_file_end_time'] - bouts_df['wav_file_start_time']
            
            plt.figure(figsize=(10, 6))
            plt.hist(bouts_df['duration'], bins=30, edgecolor='black')
            plt.title(f'Bout Duration Distribution for {bird_name} Hatch {hatch_number}')
            plt.xlabel('Duration (seconds)')
            plt.ylabel('Frequency')
            plt.savefig(os.path.join(hatch_path, 'bout_duration_distribution.svg'))
            plt.close()
        except pd.errors.EmptyDataError:
            print(f"EmptyDataError: No columns to parse from file {bouts_file}")

# Function to plot and save the distribution of YOLO confidence
def plot_yolo_confidence(hatch_path, bird_name, hatch_number):
    bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_number}.csv')
    calls_file = os.path.join(hatch_path, f'results_calls_{bird_name}_{hatch_number}.csv')
    
    bouts_confidences = []
    calls_confidences = []
    
    if os.path.exists(bouts_file):
        try:
            bouts_df = pd.read_csv(bouts_file, on_bad_lines='skip')
            if not bouts_df.empty and 'confidence' in bouts_df.columns:
                bouts_confidences.extend(bouts_df['confidence'].tolist())
        except pd.errors.EmptyDataError:
            print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    if os.path.exists(calls_file):
        try:
            calls_df = pd.read_csv(calls_file, on_bad_lines='skip')
            if not calls_df.empty and 'confidence' in calls_df.columns:
                calls_confidences.extend(calls_df['confidence'].tolist())
        except pd.errors.EmptyDataError:
            print(f"EmptyDataError: No columns to parse from file {calls_file}")
    
    if bouts_confidences or calls_confidences:
        plt.figure(figsize=(10, 6))
        plt.hist(bouts_confidences, bins=30, alpha=0.5, color='blue', label='Bouts')
        plt.hist(calls_confidences, bins=30, alpha=0.5, color='red', label='Calls')
        plt.title(f'YOLO Confidence Distribution for {bird_name} Hatch {hatch_number}')
        plt.xlabel('Confidence')
        plt.ylabel('Frequency')
        plt.legend(loc='upper right')
        plt.savefig(os.path.join(hatch_path, 'bout_confidence_distribution.svg'))
        plt.close()


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        
        if not os.path.isdir(hatch_path):
            continue
        
        bird_name = bird_dir
        hatch_number = hatch_folder
        
        # Plot and save the distribution of bout durations
        plot_bout_durations(hatch_path, bird_name, hatch_number)
        
        # Plot and save the distribution of YOLO confidence
        plot_yolo_confidence(hatch_path, bird_name, hatch_number)

print("Plots have been generated and saved successfully.")
# Out:
# Plots have been generated and saved successfully.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import numpy as np

# Base directory
base_dir = r'D:\Birdsong_581E'

# Function to plot and save the heatmap of bout duration distributions across hatch days
def plot_bout_duration_heatmap(bird_path, bird_name):
    mic_path = os.path.join(bird_path, 'mic')
    hatch_folders = [f for f in os.listdir(mic_path) if os.path.isdir(os.path.join(mic_path, f))]
    
    # Dictionary to store bout durations for each hatch day
    bout_durations = {}
    
    for hatch_folder in hatch_folders:
        hatch_path = os.path.join(mic_path, hatch_folder)
        bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_folder}.csv')
        
        if os.path.exists(bouts_file):
            try:
                bouts_df = pd.read_csv(bouts_file)
                if not bouts_df.empty:
                    bouts_df['duration'] = bouts_df['wav_file_end_time'] - bouts_df['wav_file_start_time']
                    bout_durations[hatch_folder] = bouts_df['duration'].tolist()
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    if not bout_durations:
        print(f"No valid bout data found for {bird_name}")
        return
    
    # Create a DataFrame from the dictionary
    max_duration = 6  # Limit the duration to 6 seconds
    num_bins = 20
    duration_bins = pd.cut([0, max_duration], bins=num_bins, retbins=True)[1]  # Get the bin edges
    
    heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
    
    for hatch_folder, durations in bout_durations.items():
        # Filter durations to be within 0 to 6 seconds
        filtered_durations = [d for d in durations if 0 <= d <= max_duration]
        if filtered_durations:
            duration_counts = pd.cut(filtered_durations, bins=duration_bins).value_counts()
            heatmap_data.loc[hatch_folder] = duration_counts.values
    
    # Normalize the data to represent probabilities
    heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0).fillna(0)
    
    # Plot the heatmap
    plt.figure(figsize=(12, 8))
    sns.heatmap(heatmap_data, cmap="YlGnBu", cbar_kws={'label': 'Probability'}, xticklabels=[f'{x:.2f}' for x in duration_bins[:-1]])
    plt.title(f'Bout Duration Distribution Heatmap for {bird_name}')
    plt.xlabel('Duration (seconds)')
    plt.ylabel('Hatch Day')
    # Rotate x-axis labels vertically
    plt.xticks(rotation=90)
    # Save the heatmap as a vector image
    heatmap_file = os.path.join(bird_path, 'bout_duration_heatmap.svg')
    plt.savefig(heatmap_file)
    plt.close()
    print(f"Heatmap saved for {bird_name} at {heatmap_file}")


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    bird_name = bird_dir
    
    # Plot and save the heatmap of bout duration distributions across hatch days
    plot_bout_duration_heatmap(bird_path, bird_name)

print("Heatmaps have been generated and saved successfully.")

# Function to plot and save the number of bouts detected per hatch day
def plot_bout_counts_per_hatch_day(bird_path, bird_name):
    mic_path = os.path.join(bird_path, 'mic')
    hatch_folders = [f for f in os.listdir(mic_path) if os.path.isdir(os.path.join(mic_path, f))]
    
    # Dictionary to store the number of bouts for each hatch day
    bout_counts = {}

    for hatch_folder in hatch_folders:
        hatch_path = os.path.join(mic_path, hatch_folder)
        bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_folder}.csv')
        
        if os.path.exists(bouts_file):
            try:
                bouts_df = pd.read_csv(bouts_file)
                if not bouts_df.empty:
                    # Count the number of bouts for this hatch day
                    bout_counts[hatch_folder] = len(bouts_df)
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    if not bout_counts:
        print(f"No valid bout data found for {bird_name}")
        return
    
    # Sort bout counts by hatch day
    bout_counts = {k: v for k, v in sorted(bout_counts.items(), key=lambda item: int(item[0]))}
    
    # Plot the bout counts
    plt.figure(figsize=(10, 6))
    plt.bar(bout_counts.keys(), bout_counts.values(), color='skyblue', edgecolor='black')
    plt.title(f'Number of Bouts Detected per Hatch Day for {bird_name}')
    plt.xlabel('Hatch Day')
    plt.ylabel('Number of Bouts')
    # Rotate x-axis labels vertically
    plt.xticks(rotation=90)
    # Save the figure as an SVG file
    bouts_count_svg = os.path.join(bird_path, 'bout_counts_per_hatch_day.svg')
    plt.savefig(bouts_count_svg)
    plt.close()
    print(f"SVG plot saved for {bird_name} at {bouts_count_svg}")


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    bird_name = bird_dir
    
    # Plot and save the number of bouts detected per hatch day
    plot_bout_counts_per_hatch_day(bird_path, bird_name)

print("Bout count plots have been generated and saved successfully.")

# Function to extract the hour from the filename
def extract_hour_from_filename(filename):
    # Assuming the filename format is B028_45423.68911763_5_11_19_8_31.wav
    match = re.search(r'_(\d+)_(\d+)_(\d+)_(\d+)_\d+\.wav', filename)  # Extracting the part with _5_11_19_8_31
    if match:
        hour = match.group(3)  # The third group (19 in the example) is the hour
        return int(hour)
    return None

# Function to calculate and plot the average number of bouts per hour of the day
def plot_avg_bouts_per_hour(bird_path, bird_name):
    mic_path = os.path.join(bird_path, 'mic')
    hatch_folders = [f for f in os.listdir(mic_path) if os.path.isdir(os.path.join(mic_path, f))]
    
    # Dictionary to store bout counts per hour for each hatch day
    bouts_per_hour = {hour: [] for hour in range(24)}  # A dictionary of lists to collect counts for each hatch day
    
    for hatch_folder in hatch_folders:
        hatch_path = os.path.join(mic_path, hatch_folder)
        bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_folder}.csv')
        
        if os.path.exists(bouts_file):
            try:
                bouts_df = pd.read_csv(bouts_file)
                if not bouts_df.empty:
                    # Create a temporary dictionary to count the bouts for each hour in this hatch day
                    hatch_bouts_per_hour = {hour: 0 for hour in range(24)}
                    
                    # Extract the hour from the filename for each bout and count it
                    for _, row in bouts_df.iterrows():
                        hour = extract_hour_from_filename(row['wav_filename'])
                        if hour is not None:
                            hatch_bouts_per_hour[hour] += 1  # Increment the count for the detected hour
                    
                    # Append the counts for each hour to the main bouts_per_hour dictionary
                    for hour, count in hatch_bouts_per_hour.items():
                        bouts_per_hour[hour].append(count)  # Append the count for this hour
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    # Calculate the average and standard deviation of bouts per hour across all hatch days
    avg_bouts_per_hour = []
    std_bouts_per_hour = []
    
    for hour in range(24):
        if bouts_per_hour[hour]:
            avg_bouts_per_hour.append(np.mean(bouts_per_hour[hour]))
            std_bouts_per_hour.append(np.std(bouts_per_hour[hour]))
        else:
            avg_bouts_per_hour.append(0)
            std_bouts_per_hour.append(0)
    
    # Plot the average number of bouts per hour and the standard deviation as a shadow
    hours = range(24)
    avg_bouts_per_hour = np.array(avg_bouts_per_hour)
    std_bouts_per_hour = np.array(std_bouts_per_hour)
    
    plt.figure(figsize=(10, 6))
    
    # Plot the average line
    plt.plot(hours, avg_bouts_per_hour, 'b-', label='Average Bouts')
    
    # Plot the shaded area for standard deviation
    plt.fill_between(hours, avg_bouts_per_hour - std_bouts_per_hour, avg_bouts_per_hour + std_bouts_per_hour, color='blue', alpha=0.2, label='Standard Deviation')
    
    plt.title(f'Average Number of Bouts per Hour for {bird_name}')
    plt.xlabel('Hour of the Day')
    plt.ylabel('Average Number of Bouts')
    plt.xticks(hours)
    plt.grid(True)
    
    # Save the figure as an SVG file
    avg_bouts_svg = os.path.join(bird_path, 'avg_bouts_per_hour.svg')
    plt.savefig(avg_bouts_svg)
    plt.close()
    print(f"SVG plot saved for {bird_name} at {avg_bouts_svg}")

# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    bird_name = bird_dir
    
    # Plot and save the average number of bouts per hour of the day
    plot_avg_bouts_per_hour(bird_path, bird_name)

print("Average bouts per hour plots have been generated and saved successfully.")
# Out:
# C:\Users\ucsfg\AppData\Local\Temp\ipykernel_19408\306976074.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
# C:\Users\ucsfg\AppData\Local\Temp\ipykernel_19408\306976074.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
# Heatmap saved for R07 at D:\Birdsong_581E\R07\bout_duration_heatmap.svg
# Heatmap saved for R108 at D:\Birdsong_581E\R108\bout_duration_heatmap.svg
# C:\Users\ucsfg\AppData\Local\Temp\ipykernel_19408\306976074.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
# C:\Users\ucsfg\AppData\Local\Temp\ipykernel_19408\306976074.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
# Heatmap saved for R158 at D:\Birdsong_581E\R158\bout_duration_heatmap.svg
# Heatmap saved for R160 at D:\Birdsong_581E\R160\bout_duration_heatmap.svg
# C:\Users\ucsfg\AppData\Local\Temp\ipykernel_19408\306976074.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
# Heatmap saved for R23_hatchlings at D:\Birdsong_581E\R23_hatchlings\bout_duration_heatmap.svg
# No valid bout data found for R90
# No valid bout data found for R93
# No valid bout data found for W35
# No valid bout data found for W37
# No valid bout data found for W40
# No valid bout data found for W89
# No valid bout data found for W92
# No valid bout data found for Y27
# No valid bout data found for Y40
# Heatmaps have been generated and saved successfully.
# SVG plot saved for R07 at D:\Birdsong_581E\R07\bout_counts_per_hatch_day.svg
# SVG plot saved for R108 at D:\Birdsong_581E\R108\bout_counts_per_hatch_day.svg
# SVG plot saved for R158 at D:\Birdsong_581E\R158\bout_counts_per_hatch_day.svg
# SVG plot saved for R160 at D:\Birdsong_581E\R160\bout_counts_per_hatch_day.svg
# SVG plot saved for R23_hatchlings at D:\Birdsong_581E\R23_hatchlings\bout_counts_per_hatch_day.svg
# No valid bout data found for R90
# No valid bout data found for R93
# No valid bout data found for W35
# No valid bout data found for W37
# No valid bout data found for W40
# No valid bout data found for W89
# No valid bout data found for W92
# No valid bout data found for Y27
# No valid bout data found for Y40
# Bout count plots have been generated and saved successfully.
# SVG plot saved for R07 at D:\Birdsong_581E\R07\avg_bouts_per_hour.svg
# SVG plot saved for R108 at D:\Birdsong_581E\R108\avg_bouts_per_hour.svg
# SVG plot saved for R158 at D:\Birdsong_581E\R158\avg_bouts_per_hour.svg
# SVG plot saved for R160 at D:\Birdsong_581E\R160\avg_bouts_per_hour.svg
# SVG plot saved for R23_hatchlings at D:\Birdsong_581E\R23_hatchlings\avg_bouts_per_hour.svg
# SVG plot saved for R90 at D:\Birdsong_581E\R90\avg_bouts_per_hour.svg
# SVG plot saved for R93 at D:\Birdsong_581E\R93\avg_bouts_per_hour.svg
# SVG plot saved for W35 at D:\Birdsong_581E\W35\avg_bouts_per_hour.svg
# SVG plot saved for W37 at D:\Birdsong_581E\W37\avg_bouts_per_hour.svg
# SVG plot saved for W40 at D:\Birdsong_581E\W40\avg_bouts_per_hour.svg
# SVG plot saved for W89 at D:\Birdsong_581E\W89\avg_bouts_per_hour.svg
# SVG plot saved for W92 at D:\Birdsong_581E\W92\avg_bouts_per_hour.svg
# SVG plot saved for Y27 at D:\Birdsong_581E\Y27\avg_bouts_per_hour.svg
# SVG plot saved for Y40 at D:\Birdsong_581E\Y40\avg_bouts_per_hour.svg
# Average bouts per hour plots have been generated and saved successfully.

# %% [markdown]
# # bout Entropy analytics
#
# This script processes bird song recordings to calculate and visualize the spectral entropy of detected bouts. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `pandas`, `numpy`, `scipy`, and `matplotlib`.
#
# 2. **Define Function**:
#     - `calculate_spectral_entropy`: This function computes the spectral entropy of a given signal using the Short-Time Fourier Transform (STFT).
#
# 3. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories.
#     - It loads the results from `results_bouts.csv` if available.
#
# 5. **Process Each Bout**:
#     - For each bout in the CSV file, the corresponding WAV file is read.
#     - A region of interest (ROI) around the bout is extracted with 1-second padding.
#     - The spectral entropy of the bout signal is calculated and stored.
#
# 6. **Sort and Align Bouts**:
#     - The bouts are sorted based on their total spectral entropy.
#     - All bouts are aligned to a common signal at the start of the bout using cross-correlation.
#
# 7. **Visualize Spectral Entropy**:
#     - A figure is created where each row represents a bout, the x-axis is time, and the color represents the spectral entropy.
#     - The figure is saved as an SVG file and displayed.
#
# This script helps in analyzing and visualizing the complexity of bird songs by calculating and aligning the spectral entropy of detected bouts.

# %%
import os
import pandas as pd
import numpy as np
from scipy.io import wavfile
from scipy.signal import spectrogram
import matplotlib.pyplot as plt

# Function to calculate spectral entropy
def calculate_spectral_entropy(signal, fs, nperseg=256, noverlap=128):
    f, t, Sxx = spectrogram(signal, fs, nperseg=nperseg, noverlap=noverlap)
    Sxx_norm = Sxx / np.sum(Sxx, axis=0)
    spectral_entropy = -np.sum(Sxx_norm * np.log2(Sxx_norm + 1e-10), axis=0)
    return spectral_entropy

# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        
        if not os.path.isdir(hatch_path):
            continue
        
        songs_dir = os.path.join(hatch_path, 'Songs')
        noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')
        
        if not os.path.exists(songs_dir) or not os.path.exists(noise_calls_dir):
            continue
        
        # Load results from CSV
        results_csv = os.path.join(hatch_path, 'results_bouts.csv')
        if not os.path.exists(results_csv):
            continue
        
        results_df = pd.read_csv(results_csv)

        # Process each bout
        bouts = []
        for index, row in results_df.iterrows():
            wav_file = row['wav_filename']
            wav_file_path = os.path.join(songs_dir, wav_file)
            try:
                fs, data = wavfile.read(wav_file_path)
            except PermissionError as e:
                print(f"PermissionError: {e}")
                continue
            
            roi_wav_start = int(row['wav_file_start_time'] * fs)
            roi_wav_end = int(row['wav_file_end_time'] * fs)
            
            # Add 1 second padding at start and end of each bout
            start_idx = max(0, roi_wav_start - fs)
            end_idx = min(len(data), roi_wav_end + fs)
            
            bout_signal = data[start_idx:end_idx]
            spectral_entropy = calculate_spectral_entropy(bout_signal, fs)
            
            bouts.append({
                'spectral_entropy': spectral_entropy,
                'total_spectral_entropy': np.sum(spectral_entropy),
                'start_idx': start_idx,
                'end_idx': end_idx,
                'wav_file': wav_file_path
            })

        # Sort bouts based on total summed spectral entropy
        bouts.sort(key=lambda x: x['total_spectral_entropy'], reverse=True)

        # Align all bouts to the common signal at the start of the bout
        aligned_bouts = []
        reference_bout = bouts[0]['spectral_entropy']
        for bout in bouts:
            correlation = np.correlate(reference_bout, bout['spectral_entropy'], mode='full')
            shift = np.argmax(correlation) - len(reference_bout) + 1
            aligned_bout = np.roll(bout['spectral_entropy'], shift)
            aligned_bouts.append(aligned_bout)

        # Make a figure in which each row is a bout, the x-axis is time, and the color is the spectral entropy
        plt.figure(figsize=(10, len(aligned_bouts)))
        for i, aligned_bout in enumerate(aligned_bouts):
            plt.imshow(aligned_bout[np.newaxis, :], aspect='auto', cmap='viridis', extent=[0, len(aligned_bout) / fs, i, i + 1])
        
        plt.xlabel('Time (s)')
        plt.ylabel('Bout')
        plt.yticks(np.arange(len(aligned_bouts)) + 0.5, np.arange(1, len(aligned_bouts) + 1))
        plt.gca().invert_yaxis()
        plt.tight_layout()
        output_svg = os.path.join(hatch_path, 'bouts_spectral_entropy.svg')
        plt.savefig(output_svg, format='svg')
        plt.show()
