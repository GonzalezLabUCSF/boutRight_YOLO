# %% [markdown]
# # boutRight Code Description
#
# The boutRight project processes bird song recordings to detect and classify bouts using a YOLOv5 model. The code is divided into two main parts:
#
# ## Part 1: Setup and Function Definitions
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `glob`, `shutil`, `torch`, `PIL`, `numpy`, `scipy`, `tqdm`, `io`, `IPython.display`, `concurrent.futures`, `uuid`, `pandas`, and `math`.
#
# 2. **Load YOLOv5 Model**: The YOLOv5 model is loaded with custom weights for detecting bouts in spectrogram images.
#
# 3. **Define Functions**:
#     - `filtered_spectrogram`: Filters and generates a spectrogram from a given audio file. It applies a Butterworth filter, normalizes the signal, and calculates the spectrogram.
#     - `check_for_bouts`: Generates a spectrogram image, uses the YOLOv5 model to detect bouts, and returns the detection results.
#     - `process_wav_file`: Processes each WAV file, moves it to the appropriate directory (`Songs` or `Noise_Calls`), and appends the detection results to CSV files.
#     - `append_to_csv`: Appends detection results to a CSV file, ensuring consistent data formatting.
#     - `get_all_wav_files`: Retrieves all WAV files in a directory, including subdirectories.
#     - `is_already_scanned`: Checks if a file has already been scanned by looking it up in a list of scanned files.
#
# ## Part 2: Processing Bird Song Recordings
#
# 1. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 2. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories and creates them if they don't exist.
#     - It loads the list of already scanned files from `wav_scanned.csv` if available.
#
# 3. **Process WAV Files**:
#     - The script retrieves all WAV files in the hatch day folder, including subdirectories.
#     - It uses a thread pool to process each WAV file concurrently.
#     - For each file, it generates a spectrogram, detects bouts using the YOLOv5 model, and categorizes the files into `Songs` or `Noise_Calls`.
#     - Detection results are appended to `results_bouts.csv` and `results_calls.csv`.
#
# 4. **Handle Duplicates**:
#     - If a file has already been scanned and is detected as a duplicate, a warning is displayed, and the file is deleted.
#
# 5. **Save Scanned Files**:
#     - The list of scanned files is saved to `wav_scanned.csv` to keep track of processed files and avoid reprocessing.
#
# ## Summary
#
# This script is essential for preprocessing and analyzing bird song recordings, enabling the detection and classification of bouts. It ensures efficient processing, categorization, and management of bird song data, facilitating further analysis and research.

# %%
import os
from glob import glob
import shutil
import torch
from PIL import Image
import numpy as np
from scipy.io import wavfile
from scipy import signal
from tqdm import tqdm
import io
from IPython.display import clear_output
import concurrent.futures
import uuid
import pandas as pd
import math
import zipfile
import warnings
import threading
import hashlib

# Initialize a lock object
lock = threading.Lock()

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'custom', path=os.path.join(os.getcwd(),r'yolov5\runs\train\exp13\weights\best.pt'))
#folder to temporarily save images for YOLO detection
#this is needed to run parallel computing without problems
temp_path = r'C:\Temp'

# Function to filter and generate spectrogram
def filtered_spectrogram(filepath):
    # Length of FFT
    lend = 34
    # Overlap of FFT
    overlap = 33
    # Time length for exponential window of FFT
    ts = 3
    # Low cut frequency in Hz
    lc = 500
    # High cut frequency in Hz
    hc = 20000
    # Color of image settings
    # Contribution of each channel to color
    RGBch = [0.8, 1.5, 1.5]

    # Import the audio data
    fs, data = wavfile.read(filepath)
    # Round length of data and overlap
    lend = round((lend / 1E3) * fs)
    overlap = round((overlap / 1E3) * fs)
    # Next power of two definition
    def nextpow2(x):
        return 1 if x == 0 else 2**math.ceil(math.log2(x))
    # Calculate next power of two
    nfft = nextpow2(lend)

    # Butterworth filter
    def butter_bp(data, lc, hc, fs, order=3):
        nyq = 0.5 * fs
        low = lc / nyq
        high = hc / nyq
        b, a = signal.butter(order, [low, high], btype='band')
        data_filtered = signal.lfilter(b, a, data)
        return data_filtered

    data = butter_bp(data, lc, hc, fs, order=5)
    # Normalize signal
    data = data / max(abs(data))
    # Make windows for spectrogram
    t = np.linspace(-lend / 2 + 1, lend / 2, num=lend)
    sigma = (ts / 1E3) * fs
    w = np.exp(-(t / sigma)**2)
    dw = np.exp(-(t / (2 * sigma))**2)
    # Calculate spectrograms
    [f, t, sx] = signal.spectrogram(data, fs=fs, window=w, noverlap=overlap, nfft=nfft)
    [_, _, sxx] = signal.spectrogram(data, fs=fs, window=dw, noverlap=overlap, nfft=nfft)
    # Average of both spectrograms
    image_array = np.log2(abs(sx) + abs(sxx)) / 2
    # Obtain thresholds for background
    minmax = [np.percentile(image_array, 80), np.percentile(image_array, 99)]
    # Subtract background
    image_array = np.minimum(image_array, minmax[1])
    image_array = np.maximum(image_array, minmax[0])
    # Normalize
    image_array = (image_array - np.min(image_array)) / (np.max(image_array) - np.min(image_array))
    # Flip spectrogram
    image_array = np.flip(image_array, 0)
    # Convert to color
    sz = (image_array.shape[0] - 1, image_array.shape[1] - 1, 3)
    image_color = np.zeros(sz)
    tmp = image_array
    image_color[:, :, 0] = RGBch[0] * tmp[0:-1, 0:-1]
    tmp = np.diff(image_array, 1, axis=0)
    image_color[:, :, 1] = RGBch[1] * tmp[:, 0:-1]
    tmp = np.diff(image_array, 1, axis=1)
    image_color[:, :, 2] = RGBch[2] * tmp[0:-1, :]
    
    return image_color, fs, len(data)

# Function to generate spectrogram and check for bouts using YOLOv5
def check_for_bouts(wav_file, temp_path):
    temp_img_path = None
    try:
        # Ensure the temp_path directory exists
        os.makedirs(temp_path, exist_ok=True)
        
        # Generate the spectrogram and convert it to an image
        spectrogram, fs, data_length = filtered_spectrogram(wav_file)
        spectrogram_image = (spectrogram * 255).astype(np.uint8)
        pil_image = Image.fromarray(spectrogram_image)
        
        # Generate a unique filename for the temporary spectrogram image in the temp_path directory
        temp_img_filename = f'temp_spectrogram_{uuid.uuid4().hex}.png'
        temp_img_path = os.path.join(temp_path, temp_img_filename)
        pil_image.save(temp_img_path)
        
        # Verify the saved image
        with Image.open(temp_img_path) as img:
            img.verify()
        
        # Use YOLOv5 to detect bouts in the spectrogram image
        results = model(temp_img_path)
        
        # Filter detections to only include bouts (class 0)
        bouts = [bbox for bbox in results.xyxy[0] if bbox[5] == 0]
        
        # Check if any bouts are detected
        return len(bouts) > 0, results.xyxy[0], spectrogram.shape[1], data_length, fs
    except ValueError as e:
        if "File format" in str(e):
            print(f"Error in check_for_bouts for {wav_file}: {e}")
        else:
            raise e  # Re-raise other types of ValueErrors
        return False, [], 0, 0, 0
    except Exception as e:
        print(f"Error in check_for_bouts for {wav_file}: {e}")
        return False, [], 0, 0, 0
    finally:
        # Remove the temporary image file
        if temp_img_path and os.path.exists(temp_img_path):
            os.remove(temp_img_path)


# Function to process WAV file
def process_wav_file(wav_file, songs_dir, noise_calls_dir, bouts_csv_path, calls_csv_path, scanned_files, scanned_csv_path, processed_files):
    try:
        has_bouts, bboxes, spectrogram_length, data_length, fs = check_for_bouts(wav_file, temp_path)

        results = []
        for bbox in bboxes:
            x1, y1, x2, y2, conf, cls = bbox
            entry = {
                'wav_folder_path': os.path.dirname(wav_file),
                'wav_filename': os.path.basename(wav_file),
                'spectrogram_start_time': x1.item(),
                'spectrogram_end_time': x2.item(),
                'wav_file_start_time': (x1.item() / spectrogram_length) * (data_length / fs),
                'wav_file_end_time': (x2.item() / spectrogram_length) * (data_length / fs),
                'confidence': conf.item(),
                'label_class': cls.item(),
                'bbox_x1': x1.item(),
                'bbox_y1': y1.item(),
                'bbox_x2': x2.item(),
                'bbox_y2': y2.item()
            }
            results.append(entry)

        # Append results to CSV files
        if results:
            bouts_results = [entry for entry in results if entry['label_class'] == 0]
            calls_results = [entry for entry in results if entry['label_class'] == 1]

            with lock:
                if bouts_results:
                    append_to_csv(bouts_results, bouts_csv_path)
                if calls_results:
                    append_to_csv(calls_results, calls_csv_path)

        # Move the file based on detection results
        if has_bouts:
            shutil.move(wav_file, os.path.join(songs_dir, os.path.basename(wav_file)))
            with lock:
                processed_files.add(os.path.basename(wav_file))  # Thread-safe addition
            print(f"Moved {wav_file} to Songs")
        else:
            shutil.move(wav_file, os.path.join(noise_calls_dir, os.path.basename(wav_file)))
            print(f"Moved {wav_file} to Noise_Calls")

        # Update scanned files and save to CSV immediately
        with lock:
            scanned_files.append(os.path.basename(wav_file))
            pd.DataFrame({'filename': scanned_files}).to_csv(scanned_csv_path, index=False)

        return {
            'filepath': wav_file,
            'filename': os.path.basename(wav_file),
            'bboxes': bboxes,
            'spectrogram_length': spectrogram_length,
            'data_length': data_length,
            'fs': fs
        }
    except Exception as e:
        print(f"Error processing {wav_file}: {e}")
        return None

# Function to re-process WAV file that was missed in the original scan
def reprocess_wav_file(wav_file, noise_calls_dir, bouts_csv_path, calls_csv_path):
    try:
        has_bouts, bboxes, spectrogram_length, data_length, fs = check_for_bouts(wav_file, temp_path)

        results = []
        for bbox in bboxes:
            x1, y1, x2, y2, conf, cls = bbox
            entry = {
                'wav_folder_path': os.path.dirname(wav_file),
                'wav_filename': os.path.basename(wav_file),
                'spectrogram_start_time': x1.item(),
                'spectrogram_end_time': x2.item(),
                'wav_file_start_time': (x1.item() / spectrogram_length) * (data_length / fs),
                'wav_file_end_time': (x2.item() / spectrogram_length) * (data_length / fs),
                'confidence': conf.item(),
                'label_class': cls.item(),
                'bbox_x1': x1.item(),
                'bbox_y1': y1.item(),
                'bbox_x2': x2.item(),
                'bbox_y2': y2.item()
            }
            results.append(entry)

        # Append results to CSV files
        if results:
            bouts_results = [entry for entry in results if entry['label_class'] == 0]
            calls_results = [entry for entry in results if entry['label_class'] == 1]

            with lock:
                if bouts_results:
                    append_to_csv(bouts_results, bouts_csv_path)
                if calls_results:
                    append_to_csv(calls_results, calls_csv_path)

        if has_bouts:
            print(f"Reprocessed and found bouts in {wav_file}")
        else:
            print(f"Reprocessed {wav_file}, no bouts found")
            
            # Add this block to move files without bouts to the Noise_Calls folder
            shutil.move(wav_file, os.path.join(noise_calls_dir, os.path.basename(wav_file)))
            print(f"Moved {wav_file} to Noise_Calls after re-scan")

    except Exception as e:
        print(f"Error reprocessing {wav_file}: {e}")


# Function to append results to CSV
def append_to_csv(results, csv_path):
    # Define the expected columns
    columns = [
        'wav_folder_path', 'wav_filename', 'spectrogram_start_time', 'spectrogram_end_time',
        'wav_file_start_time', 'wav_file_end_time', 'confidence', 'label_class',
        'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2'
    ]
    
    # Convert results to DataFrame
    new_df = pd.DataFrame(results, columns=columns)
    
    # Append to the CSV file
    if os.path.exists(csv_path):
        new_df.to_csv(csv_path, mode='a', header=False, index=False)
    else:
        new_df.to_csv(csv_path, mode='w', header=True, index=False)

# Function to hash individual files to avoid duplicates
def hash_file(filepath):
    """Returns the MD5 hash of the file content."""
    hasher = hashlib.md5()
    with open(filepath, 'rb') as file:
        buf = file.read()
        hasher.update(buf)
    return hasher.hexdigest()

# Function to gather filename of wav files in folders and zip files
def get_all_wav_files(hatch_path, bird_path):
    wav_files = {}  # Use a dictionary to avoid duplicates by file content hash
    songs_dir = os.path.join(hatch_path, 'Songs')
    noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')

    # Extract ZIP files recursively
    zip_files = glob(os.path.join(hatch_path, '**', '*.zip'), recursive=True)
    for zip_file in zip_files:
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall(hatch_path)
        
        # Move the ZIP file to the birdname folder (at the same level as the mic folder)
        shutil.move(zip_file, os.path.join(bird_path, os.path.basename(zip_file)))

    # Function to add files based on their content hash
    def add_wav_files(dir_path):
        for wav_file in glob(os.path.join(dir_path, '**', '*.wav'), recursive=True):
            file_hash = hash_file(wav_file)
            if file_hash not in wav_files:
                wav_files[file_hash] = wav_file
    
    # Add WAV files from the main directory, Songs, and Noise_Calls
    add_wav_files(hatch_path)
    if os.path.exists(songs_dir):
        add_wav_files(songs_dir)
    if os.path.exists(noise_calls_dir):
        add_wav_files(noise_calls_dir)
    
    return list(wav_files.values())  # Return only the unique file paths

# Function to check if a file has already been scanned
def is_already_scanned(wav_file, scanned_files):
    return os.path.basename(wav_file) in scanned_files

# Function to check if a song file is in the bouts CSV
def is_in_bouts_csv(wav_file, bouts_csv_path):
    if os.path.exists(bouts_csv_path):
        try:
            bouts_df = pd.read_csv(bouts_csv_path)
            return os.path.basename(wav_file) in bouts_df['wav_filename'].values
        except pd.errors.EmptyDataError:
            return False
    return False
# Out:
# Using cache found in C:\Users\Gonzalez Lab/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-9-4 Python-3.12.5 torch-2.4.0 CPU
#
# Fusing layers...
# Model summary: 166 layers, 7056607 parameters, 0 gradients
# Adding AutoShape...

# %%
# Manually set the selected birds for scanning
# You can list one bird or multiple birds here
# Example: selected_birds = ['bird01', 'bird03'] or selected_birds = ['bird01'] for one bird
# If you want to process all birds, you can set selected_birds = ['all']

# Base directory and suppression of warnings remain unchanged
base_dir = r'G:\Lab Dropbox\BirdSong\BirdData_2024'
warnings.filterwarnings("ignore", category=FutureWarning, message=".*torch.cuda.amp.autocast.*")

# List all available birds
available_birds = [bird for bird in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, bird))]

# Manually set the birds you want to process
# Example: selected_birds = ['bird01', 'bird02']
selected_birds = ['R97']  # Set to process all birds, or you can choose specific birds

# Main processing function for each bird
def process_bird(bird_name, base_dir):
    bird_path = os.path.join(base_dir, bird_name)
    mic_path = os.path.join(bird_path, 'mic')

    if not os.path.exists(mic_path):
        print(f"No 'mic' folder found for {bird_name}.")
        return

    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        bird_name = bird_name  # Corrected this to use bird_name from function
        hatch_day = hatch_folder    

        if not os.path.isdir(hatch_path):
            continue

        songs_dir = os.path.join(hatch_path, 'Songs')
        noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')

        # Create Songs and Noise_Calls directories if they don't exist
        os.makedirs(songs_dir, exist_ok=True)
        os.makedirs(noise_calls_dir, exist_ok=True)

        bouts_csv_path = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_day}.csv')
        calls_csv_path = os.path.join(hatch_path, f'results_calls_{bird_name}_{hatch_day}.csv')
        scanned_csv_path = os.path.join(hatch_path, f'wav_scanned_{bird_name}_{hatch_day}.csv')
        print(f"Processing: {bouts_csv_path}")
        
        scanned_files = []
        if os.path.exists(scanned_csv_path):
            try:
                scanned_df = pd.read_csv(scanned_csv_path, on_bad_lines='skip')
                scanned_files = scanned_df['filename'].tolist()
            except pd.errors.EmptyDataError:
                scanned_files = []

        wav_files = get_all_wav_files(hatch_path, bird_path)

        # Filter out already scanned files
        unscanned_wav_files = [wav_file for wav_file in wav_files if not is_already_scanned(wav_file, scanned_files)]

        processed_files = set()  # Thread-safe modification

        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = {executor.submit(process_wav_file, wav_file, songs_dir, noise_calls_dir, bouts_csv_path, calls_csv_path, scanned_files, scanned_csv_path, processed_files): wav_file for wav_file in unscanned_wav_files}
            for i, future in enumerate(tqdm(concurrent.futures.as_completed(futures), total=len(unscanned_wav_files), desc="Processing WAV files")):
                if i % 10 == 0:
                    clear_output(wait=True)  # Clear the output every 10 files
                wav_file = futures[future]
                try:
                    result = future.result()
                except Exception as exc:
                    print(f'{wav_file} generated an exception: {exc}')

        # Final check: Ensure all files in Songs appear in both wav_scanned.csv and results_bouts.csv
        song_files_to_rescan = []
        for song_file in glob(os.path.join(songs_dir, '*.wav')):
            if not is_already_scanned(song_file, scanned_files):
                print(f"Appending {song_file} to scanned files")
                with lock:
                    scanned_files.append(os.path.basename(song_file))
                    pd.DataFrame({'filename': scanned_files}).to_csv(scanned_csv_path, index=False)
            if not is_in_bouts_csv(song_file, bouts_csv_path):
                print(f"File {song_file} missing from results_bouts.csv, adding to re-scan list")
                song_files_to_rescan.append(song_file)

        # Parallel processing for the re-scan of song files
        with concurrent.futures.ThreadPoolExecutor() as reprocess_executor:
            reprocess_futures = {reprocess_executor.submit(reprocess_wav_file, song_file, noise_calls_dir, bouts_csv_path, calls_csv_path): song_file for song_file in song_files_to_rescan}
            for i, future in enumerate(tqdm(concurrent.futures.as_completed(reprocess_futures), total=len(song_files_to_rescan), desc="Re-scanning Songs")):
                if i % 10 == 0:
                    clear_output(wait=True)  # Clear the output every 10 iterations
                song_file = reprocess_futures[future]
                try:
                    future.result()
                except Exception as exc:
                    print(f'{song_file} generated an exception during re-scan: {exc}')


# Process the selected birds
if selected_birds:
    for bird in selected_birds:
        process_bird(bird, base_dir)
else:
    print("No birds selected. Exiting...")
# Out:
# Processing: G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\168\results_bouts_R97_168.csv

# %% [markdown]
# # Remove noise and call wav files which have the least amount of calls
#
# This script processes bird song recordings to manage and retain the top 100 WAV files with the most calls in each hatch day folder. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `pandas`, and `glob`.
#
# 2. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 3. **Define Function**:
#     - `process_hatch_day_folder`: This function processes each hatch day folder by:
#         - Checking if the `results_calls.csv` file exists.
#         - Loading the CSV file and counting the number of calls in each WAV file.
#         - Sorting the files by call count and retaining the top 100.
#         - Deleting the remaining files in the `Noise_Calls` folder.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it calls the `process_hatch_day_folder` function to manage the WAV files based on the number of calls.
#
# This script helps in organizing and retaining the most relevant bird song recordings for further analysis.

# %%
import os
import csv
import pandas as pd
from glob import glob

# Base directory
base_dir = r'G:\Lab Dropbox\BirdSong\BirdData_2024'

# Function to process each hatch day folder
def process_hatch_day_folder(hatch_path, bird_name, hatch_day):
    calls_csv_path = os.path.join(hatch_path, f'results_calls_{bird_name}_{hatch_day}.csv')
    noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')
    
    # Check if the calls CSV file exists
    if not os.path.exists(calls_csv_path):
        print(f"No CSV file found for {hatch_path}. Skipping...")
        return
    
    try:
        # Load the calls CSV file
        calls_df = pd.read_csv(calls_csv_path, on_bad_lines='skip')
        
        if calls_df.empty:
            print(f"No data in {calls_csv_path}. Skipping...")
            return
        
        # Group by filename and count the number of calls
        call_counts = calls_df.groupby('wav_filename').size().reset_index(name='call_count')
        
        # Sort by call count in descending order and keep the top 100
        top_calls = call_counts.sort_values(by='call_count', ascending=False).head(100)
        
        # Get the list of top 100 filenames
        top_filenames = top_calls['wav_filename'].tolist()
        
        # Get all WAV files in the Noise_Calls folder
        all_wav_files = glob(os.path.join(noise_calls_dir, '*.wav'))
        
        # Delete files not in the top 100
        for wav_file in all_wav_files:
            if os.path.basename(wav_file) not in top_filenames:
                os.remove(wav_file)
                print(f"Deleted {wav_file}")
    except pd.errors.EmptyDataError:
        print(f"EmptyDataError: No columns to parse from file {calls_csv_path}")

# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        
        if not os.path.isdir(hatch_path):
            continue
        
        bird_name = bird_dir
        hatch_day = hatch_folder
        
        process_hatch_day_folder(hatch_path, bird_name, hatch_day)


def align_csv_columns(file_path, expected_columns=12):
    aligned_rows = []
    
    try:
        with open(file_path, 'r') as infile:
            reader = csv.reader(infile)
            for row in reader:
                # Count non-empty cells
                non_empty_cells = [cell for cell in row if cell]
                
                if len(non_empty_cells) == expected_columns:
                    # Shift the row to start at column 1 and ensure it has exactly 12 columns
                    aligned_row = non_empty_cells[:expected_columns]
                else:
                    aligned_row = row
                
                # Ensure the row has exactly 12 columns
                aligned_row = aligned_row[:expected_columns]
                
                aligned_rows.append(aligned_row)
        
        with open(file_path, 'w', newline='') as outfile:
            writer = csv.writer(outfile)
            writer.writerows(aligned_rows)
        print(f"CSV columns aligned successfully for {file_path}.")
    
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")

def process_hatch_folders(base_path, expected_columns=12):
    for root, dirs, files in os.walk(base_path):
        for file in files:
            if file.startswith('results_bout') or file.startswith('results_call'):
                file_path = os.path.join(root, file)
                align_csv_columns(file_path, expected_columns)

# Fix excel files
process_hatch_folders(base_dir)
# Out:
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\syntax_analysis. Skipping...
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23450571_5_12_6_30_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23465206_5_12_6_31_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23480686_5_12_6_31_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23512510_5_12_6_31_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23523065_5_12_6_32_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23533671_5_12_6_32_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23565540_5_12_6_32_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23597185_5_12_6_33_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23628895_5_12_6_33_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23660552_5_12_6_34_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23677378_5_12_6_34_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23686003_5_12_6_34_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23718538_5_12_6_35_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23750880_5_12_6_35_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23763455_5_12_6_36_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23795112_5_12_6_36_35.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23827151_5_12_6_37_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23859355_5_12_6_37_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23891372_5_12_6_38_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23922984_5_12_6_38_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23954953_5_12_6_39_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.23987034_5_12_6_39_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24018739_5_12_6_40_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24030581_5_12_6_40_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24072122_5_12_6_41_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24143649_5_12_6_42_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24160765_5_12_6_42_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24198725_5_12_6_43_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24210418_5_12_6_43_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24242757_5_12_6_44_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24308847_5_12_6_45_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24354960_5_12_6_45_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24367507_5_12_6_46_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24386424_5_12_6_46_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24528754_5_12_6_48_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24629379_5_12_6_50_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24655791_5_12_6_50_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24692248_5_12_6_51_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24820933_5_12_6_53_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24854654_5_12_6_54_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24915550_5_12_6_55_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.24941268_5_12_6_55_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25014793_5_12_6_56_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25045600_5_12_6_57_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25077253_5_12_6_57_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25153944_5_12_6_59_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25238722_5_12_7_0_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25260789_5_12_7_1_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25365270_5_12_7_2_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25379065_5_12_7_2_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25412499_5_12_7_3_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25457455_5_12_7_4_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25489393_5_12_7_4_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25496228_5_12_7_4_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25527885_5_12_7_5_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25779206_5_12_7_9_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25906417_5_12_7_11_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.25969670_5_12_7_12_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26000070_5_12_7_13_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26031746_5_12_7_13_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26087220_5_12_7_14_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26145880_5_12_7_15_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26238921_5_12_7_17_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26302493_5_12_7_18_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26317956_5_12_7_18_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26395994_5_12_7_19_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26422639_5_12_7_20_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26436068_5_12_7_20_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26454388_5_12_7_20_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26478744_5_12_7_21_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26534332_5_12_7_22_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26600728_5_12_7_23_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26612249_5_12_7_23_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26637992_5_12_7_23_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26659855_5_12_7_24_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26693940_5_12_7_24_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26757678_5_12_7_25_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26789326_5_12_7_26_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26821532_5_12_7_27_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26868626_5_12_7_27_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26889438_5_12_7_28_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26917620_5_12_7_28_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.26980034_5_12_7_29_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27023285_5_12_7_30_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27046638_5_12_7_30_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27140856_5_12_7_32_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27190360_5_12_7_33_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27317723_5_12_7_35_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27381462_5_12_7_36_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27413505_5_12_7_36_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27476833_5_12_7_37_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27559132_5_12_7_39_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27572415_5_12_7_39_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27631367_5_12_7_40_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27767840_5_12_7_42_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27792016_5_12_7_43_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27842540_5_12_7_44_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27854941_5_12_7_44_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27873166_5_12_7_44_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27882884_5_12_7_44_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.27899769_5_12_7_44_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28010740_5_12_7_46_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28120683_5_12_7_48_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28236061_5_12_7_50_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28241561_5_12_7_50_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28269809_5_12_7_51_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28288744_5_12_7_51_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28320405_5_12_7_52_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28352263_5_12_7_52_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28383868_5_12_7_53_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28410745_5_12_7_53_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28418955_5_12_7_53_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28451073_5_12_7_54_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28468310_5_12_7_54_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28531584_5_12_7_55_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28563200_5_12_7_56_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28627752_5_12_7_57_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28675888_5_12_7_57_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28729820_5_12_7_58_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28759340_5_12_7_59_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28774341_5_12_7_59_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28794623_5_12_7_59_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.28837884_5_12_8_0_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29066753_5_12_8_4_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29171698_5_12_8_6_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29200269_5_12_8_6_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29232014_5_12_8_7_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29263642_5_12_8_7_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29295260_5_12_8_8_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29390280_5_12_8_9_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29413920_5_12_8_10_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29456069_5_12_8_10_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29522805_5_12_8_12_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29599766_5_12_8_13_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29689600_5_12_8_14_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29721200_5_12_8_15_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29922113_5_12_8_18_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.29989357_5_12_8_19_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30268981_5_12_8_24_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30320757_5_12_8_25_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30408933_5_12_8_26_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30487738_5_12_8_28_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30516746_5_12_8_28_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30633129_5_12_8_30_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30693931_5_12_8_31_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30706971_5_12_8_31_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30729685_5_12_8_32_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30743221_5_12_8_32_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30762324_5_12_8_32_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30772393_5_12_8_32_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.30967153_5_12_8_36_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31019555_5_12_8_36_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31039274_5_12_8_37_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31063898_5_12_8_37_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31096461_5_12_8_38_16.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31129775_5_12_8_38_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31155279_5_12_8_39_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31187323_5_12_8_39_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31219647_5_12_8_40_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31248243_5_12_8_40_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31263751_5_12_8_41_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31289462_5_12_8_41_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31352465_5_12_8_42_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31381277_5_12_8_43_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31402450_5_12_8_43_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31449963_5_12_8_44_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31481385_5_12_8_44_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31532509_5_12_8_45_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31585834_5_12_8_46_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31731334_5_12_8_48_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31762965_5_12_8_49_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31771249_5_12_8_49_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31866366_5_12_8_51_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31898096_5_12_8_51_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31929852_5_12_8_52_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.31987095_5_12_8_53_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32002163_5_12_8_53_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32065492_5_12_8_54_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32128804_5_12_8_55_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32160462_5_12_8_56_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32199901_5_12_8_56_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32210773_5_12_8_56_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32243152_5_12_8_57_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32274811_5_12_8_57_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32303679_5_12_8_58_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32402119_5_12_9_0_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32479937_5_12_9_1_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32493020_5_12_9_1_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32527833_5_12_9_2_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32559824_5_12_9_2_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32623895_5_12_9_3_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32635289_5_12_9_3_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32667394_5_12_9_4_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32733639_5_12_9_5_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32760243_5_12_9_6_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32836303_5_12_9_7_16.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32869133_5_12_9_7_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32888975_5_12_9_8_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32898158_5_12_9_8_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32915457_5_12_9_8_35.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32949013_5_12_9_9_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32985394_5_12_9_9_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.32997210_5_12_9_9_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33028867_5_12_9_10_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33117125_5_12_9_11_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33132930_5_12_9_12_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33154739_5_12_9_12_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33226155_5_12_9_13_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33258365_5_12_9_14_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33290134_5_12_9_14_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33305496_5_12_9_15_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33337092_5_12_9_15_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33357113_5_12_9_15_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33375007_5_12_9_16_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33407956_5_12_9_16_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33445087_5_12_9_17_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33456558_5_12_9_17_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33466680_5_12_9_17_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33483994_5_12_9_18_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33508782_5_12_9_18_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33516904_5_12_9_18_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33535536_5_12_9_18_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33554339_5_12_9_19_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33581357_5_12_9_19_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33615415_5_12_9_20_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33636508_5_12_9_20_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33643988_5_12_9_20_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33669456_5_12_9_21_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33721159_5_12_9_22_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33743892_5_12_9_22_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33775777_5_12_9_22_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33792542_5_12_9_23_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33831135_5_12_9_23_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33895138_5_12_9_24_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33931816_5_12_9_25_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33949499_5_12_9_25_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33965250_5_12_9_26_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.33974387_5_12_9_26_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34127872_5_12_9_28_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34269960_5_12_9_31_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34277898_5_12_9_31_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34341495_5_12_9_32_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34413375_5_12_9_33_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34476650_5_12_9_34_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34508630_5_12_9_35_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34528527_5_12_9_35_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34642880_5_12_9_37_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34674811_5_12_9_37_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34706787_5_12_9_38_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34738496_5_12_9_38_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34755691_5_12_9_39_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34790234_5_12_9_39_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34822831_5_12_9_40_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34845513_5_12_9_40_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34856321_5_12_9_40_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34888096_5_12_9_41_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34919758_5_12_9_41_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.34983463_5_12_9_43_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35048161_5_12_9_44_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35155856_5_12_9_45_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35187862_5_12_9_46_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35282910_5_12_9_48_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35380323_5_12_9_49_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35443790_5_12_9_50_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35538797_5_12_9_52_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35665463_5_12_9_54_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35697436_5_12_9_54_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35729293_5_12_9_55_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35760892_5_12_9_56_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35919358_5_12_9_58_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.35983578_5_12_9_59_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36020338_5_12_10_0_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36052544_5_12_10_0_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36115758_5_12_10_1_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36172075_5_12_10_2_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36221416_5_12_10_3_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36386708_5_12_10_6_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36418324_5_12_10_6_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36450564_5_12_10_7_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36545806_5_12_10_9_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36568990_5_12_10_9_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36686146_5_12_10_11_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36692262_5_12_10_11_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.36880682_5_12_10_14_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37140722_5_12_10_19_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37210119_5_12_10_20_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37242010_5_12_10_20_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37274647_5_12_10_21_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37434401_5_12_10_23_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37485801_5_12_10_24_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37601173_5_12_10_26_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37668509_5_12_10_27_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37702361_5_12_10_28_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37708178_5_12_10_28_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37852550_5_12_10_30_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37891417_5_12_10_31_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37923374_5_12_10_32_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.37983347_5_12_10_33_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38110263_5_12_10_35_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38126542_5_12_10_35_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38138461_5_12_10_35_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38145752_5_12_10_35_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38157975_5_12_10_35_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38255237_5_12_10_37_35.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38286877_5_12_10_38_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38351103_5_12_10_39_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38414371_5_12_10_40_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38486519_5_12_10_41_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38508665_5_12_10_41_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38527900_5_12_10_42_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38543710_5_12_10_42_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38597696_5_12_10_43_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38616864_5_12_10_43_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38641663_5_12_10_44_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38673318_5_12_10_44_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38697868_5_12_10_44_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38726660_5_12_10_45_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38748887_5_12_10_45_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38864333_5_12_10_47_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38896023_5_12_10_48_16.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.38955769_5_12_10_49_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39050945_5_12_10_50_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39115691_5_12_10_51_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39214051_5_12_10_53_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39265436_5_12_10_54_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39297628_5_12_10_54_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39349468_5_12_10_55_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39404848_5_12_10_56_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39422587_5_12_10_57_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39433036_5_12_10_57_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39458537_5_12_10_57_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39471464_5_12_10_57_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39503089_5_12_10_58_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39597818_5_12_10_59_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39692742_5_12_11_1_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39724368_5_12_11_2_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39756334_5_12_11_2_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39793495_5_12_11_3_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39830975_5_12_11_3_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39868916_5_12_11_4_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39902118_5_12_11_5_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39910170_5_12_11_5_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39924384_5_12_11_5_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.39982353_5_12_11_6_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40025637_5_12_11_7_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40054212_5_12_11_7_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40062496_5_12_11_7_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40133522_5_12_11_8_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40143917_5_12_11_9_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40163342_5_12_11_9_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40178273_5_12_11_9_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40188334_5_12_11_9_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40201365_5_12_11_10_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40238339_5_12_11_10_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40253752_5_12_11_10_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40415920_5_12_11_13_35.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40439669_5_12_11_13_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40457330_5_12_11_14_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40530714_5_12_11_15_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40559278_5_12_11_15_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40666368_5_12_11_17_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40793258_5_12_11_19_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40809426_5_12_11_20_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40872755_5_12_11_21_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40904434_5_12_11_21_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40939335_5_12_11_22_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40966136_5_12_11_22_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.40999900_5_12_11_23_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41029732_5_12_11_23_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41071543_5_12_11_24_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41123217_5_12_11_25_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41262184_5_12_11_27_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41287827_5_12_11_28_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41320056_5_12_11_28_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41436592_5_12_11_30_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41468226_5_12_11_31_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41595043_5_12_11_33_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41618613_5_12_11_33_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41629377_5_12_11_33_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41654381_5_12_11_34_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41665981_5_12_11_34_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41714043_5_12_11_35_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41800888_5_12_11_36_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41849538_5_12_11_37_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.41950282_5_12_11_39_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42020971_5_12_11_40_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42032952_5_12_11_40_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42066552_5_12_11_41_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42083124_5_12_11_41_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42105836_5_12_11_41_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42140395_5_12_11_42_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42169150_5_12_11_42_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42198564_5_12_11_43_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42235839_5_12_11_43_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42338487_5_12_11_45_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42386333_5_12_11_46_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42407164_5_12_11_46_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42443584_5_12_11_47_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42464412_5_12_11_47_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.42890950_5_12_11_54_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43023270_5_12_11_57_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43046445_5_12_11_57_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43091581_5_12_11_58_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43147539_5_12_11_59_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43246043_5_12_12_0_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43281580_5_12_12_1_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43304273_5_12_12_1_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43339620_5_12_12_2_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43353797_5_12_12_2_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43409450_5_12_12_3_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43505130_5_12_12_5_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43515837_5_12_12_5_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43547874_5_12_12_5_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43593483_5_12_12_6_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43604501_5_12_12_6_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43623211_5_12_12_7_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43658072_5_12_12_7_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43708094_5_12_12_8_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43723388_5_12_12_8_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43731922_5_12_12_8_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43764260_5_12_12_9_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43828026_5_12_12_10_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43863560_5_12_12_11_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43895804_5_12_12_11_35.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.43954364_5_12_12_12_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44120522_5_12_12_15_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44246801_5_12_12_17_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44310111_5_12_12_18_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44384359_5_12_12_19_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44416116_5_12_12_20_16.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44448008_5_12_12_20_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44511009_5_12_12_21_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44542816_5_12_12_22_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44574638_5_12_12_22_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44606314_5_12_12_23_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44638130_5_12_12_23_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44670603_5_12_12_24_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44702339_5_12_12_25_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44734011_5_12_12_25_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44765706_5_12_12_26_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44797373_5_12_12_26_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44810650_5_12_12_26_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\Noise_Calls\B028_45424.44835522_5_12_12_27_15.wav
# ...
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\136\results_calls_8UWL2_136.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\137\results_bouts_8UWL2_137.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\137\results_calls_8UWL2_137.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\138\results_bouts_8UWL2_138.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\138\results_calls_8UWL2_138.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\139\results_bouts_8UWL2_139.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\139\results_calls_8UWL2_139.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\140\results_bouts_8UWL2_140.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\140\results_calls_8UWL2_140.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\141\results_bouts_8UWL2_141.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\141\results_calls_8UWL2_141.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\142\results_bouts_8UWL2_142.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\142\results_calls_8UWL2_142.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\143\results_bouts_8UWL2_143.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\143\results_calls_8UWL2_143.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\144\results_bouts_8UWL2_144.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\144\results_calls_8UWL2_144.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\145\results_bouts_8UWL2_145.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\145\results_calls_8UWL2_145.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\146\results_bouts_8UWL2_146.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\146\results_calls_8UWL2_146.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\147\results_bouts_8UWL2_147.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\147\results_calls_8UWL2_147.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\148\results_bouts_8UWL2_148.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\148\results_calls_8UWL2_148.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\149\results_bouts_8UWL2_149.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\149\results_calls_8UWL2_149.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\results_bouts_B028_100.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\results_calls_B028_100.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\101\results_bouts_B028_101.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\101\results_calls_B028_101.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\102\results_bouts_B028_102.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\102\results_calls_B028_102.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\103\results_bouts_B028_103.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\103\results_calls_B028_103.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\104\results_bouts_B028_104.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\104\results_calls_B028_104.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\105\results_bouts_B028_105.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\105\results_calls_B028_105.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\106\results_bouts_B028_106.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\106\results_calls_B028_106.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\107\results_bouts_B028_107.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\107\results_calls_B028_107.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\108\results_bouts_B028_108.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\108\results_calls_B028_108.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\109\results_bouts_B028_109.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\109\results_calls_B028_109.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\110\results_bouts_B028_110.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\110\results_calls_B028_110.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\111\results_bouts_B028_111.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\111\results_calls_B028_111.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\112\results_bouts_B028_112.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\112\results_calls_B028_112.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\113\results_bouts_B028_113.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\113\results_calls_B028_113.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\114\results_bouts_B028_114.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\114\results_calls_B028_114.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\115\results_bouts_B028_115.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\115\results_calls_B028_115.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\116\results_bouts_B028_116.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\116\results_calls_B028_116.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\117\results_bouts_B028_117.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\117\results_calls_B028_117.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\118\results_bouts_B028_118.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\118\results_calls_B028_118.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\119\results_bouts_B028_119.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\119\results_calls_B028_119.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\120\results_bouts_B028_120.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\120\results_calls_B028_120.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\121\results_bouts_B028_121.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\121\results_calls_B028_121.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\122\results_bouts_B028_122.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\122\results_calls_B028_122.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\123\results_bouts_B028_123.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\123\results_calls_B028_123.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\124\results_bouts_B028_124.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\124\results_calls_B028_124.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\125\results_bouts_B028_125.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\125\results_calls_B028_125.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\126\results_bouts_B028_126.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\126\results_calls_B028_126.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\133\results_bouts_B028_133.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\133\results_calls_B028_133.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\results_bouts_B028_134.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\134\results_calls_B028_134.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\135\results_bouts_B028_135.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\135\results_calls_B028_135.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\136\results_bouts_B028_136.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\136\results_calls_B028_136.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\137\results_bouts_B028_137.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\137\results_calls_B028_137.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\138\results_bouts_B028_138.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\138\results_calls_B028_138.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\139\results_bouts_B028_139.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\139\results_calls_B028_139.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\140\results_bouts_B028_140.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\140\results_calls_B028_140.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\141\results_bouts_B028_141.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\141\results_calls_B028_141.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\142\results_bouts_B028_142.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\142\results_calls_B028_142.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\143\results_bouts_B028_143.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\143\results_calls_B028_143.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\144\results_bouts_B028_144.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\144\results_calls_B028_144.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\145\results_bouts_B028_145.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\145\results_calls_B028_145.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\146\results_bouts_B028_146.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\146\results_calls_B028_146.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\147\results_bouts_B028_147.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\147\results_calls_B028_147.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\148\results_bouts_B028_148.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\148\results_calls_B028_148.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\149\results_bouts_B028_149.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\149\results_calls_B028_149.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\170\results_bouts_B028_170.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\170\results_calls_B028_170.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\171\results_bouts_B028_171.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\171\results_calls_B028_171.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\172\results_bouts_B028_172.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\172\results_calls_B028_172.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\173\results_bouts_B028_173.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\173\results_calls_B028_173.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\174\results_bouts_B028_174.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\174\results_calls_B028_174.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\175\results_bouts_B028_175.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\175\results_calls_B028_175.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\176\results_bouts_B028_176.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\176\results_calls_B028_176.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\177\results_bouts_B028_177.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\177\results_calls_B028_177.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\178\results_bouts_B028_178.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\178\results_calls_B028_178.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\98\results_bouts_B028_98.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\98\results_calls_B028_98.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\99\results_bouts_B028_99.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\99\results_calls_B028_99.csv.

# %% [markdown]
# # Simple bout analytics
#
# This script processes bird song recordings to generate and save plots for the distribution of bout durations and YOLO confidence scores. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `pandas`, `matplotlib.pyplot`, and `os`.
#
# 2. **Define Functions**:
#     - `plot_bout_durations`: This function calculates and plots the distribution of bout durations from the `results_bouts.csv` file. It saves the plot as an SVG file.
#     - `plot_yolo_confidence`: This function calculates and plots the distribution of YOLO confidence scores from the `results_bouts.csv` and `results_calls.csv` files. It saves the plot as an SVG file.
#
# 3. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories.
#     - It loads the results from `results_bouts.csv` and `results_calls.csv` if available.
#     - It calls the `plot_bout_durations` and `plot_yolo_confidence` functions to generate and save the plots.
#
# 5. **Output**: The script prints a message indicating that the plots have been generated and saved successfully.
#
# This script helps in visualizing the distribution of bout durations and YOLO confidence scores for bird song recordings.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Base directory
base_dir = r'G:\Lab Dropbox\BirdSong\BirdData_2024'
# Function to plot and save the distribution of bout durations
def plot_bout_durations(hatch_path, bird_name, hatch_number):
    bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_number}.csv')
    if os.path.exists(bouts_file):
        try:
            bouts_df = pd.read_csv(bouts_file)
            if bouts_df.empty:
                print(f"No data in {bouts_file}")
                return
            bouts_df['duration'] = bouts_df['wav_file_end_time'] - bouts_df['wav_file_start_time']
            
            plt.figure(figsize=(10, 6))
            plt.hist(bouts_df['duration'], bins=30, edgecolor='black')
            plt.title(f'Bout Duration Distribution for {bird_name} Hatch {hatch_number}')
            plt.xlabel('Duration (seconds)')
            plt.ylabel('Frequency')
            plt.savefig(os.path.join(hatch_path, 'bout_duration_distribution.svg'))
            plt.close()
        except pd.errors.EmptyDataError:
            print(f"EmptyDataError: No columns to parse from file {bouts_file}")

# Function to plot and save the distribution of YOLO confidence
def plot_yolo_confidence(hatch_path, bird_name, hatch_number):
    bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_number}.csv')
    calls_file = os.path.join(hatch_path, f'results_calls_{bird_name}_{hatch_number}.csv')
    
    bouts_confidences = []
    calls_confidences = []
    
    if os.path.exists(bouts_file):
        try:
            bouts_df = pd.read_csv(bouts_file, on_bad_lines='skip')
            if not bouts_df.empty and 'confidence' in bouts_df.columns:
                bouts_confidences.extend(bouts_df['confidence'].tolist())
        except pd.errors.EmptyDataError:
            print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    if os.path.exists(calls_file):
        try:
            calls_df = pd.read_csv(calls_file, on_bad_lines='skip')
            if not calls_df.empty and 'confidence' in calls_df.columns:
                calls_confidences.extend(calls_df['confidence'].tolist())
        except pd.errors.EmptyDataError:
            print(f"EmptyDataError: No columns to parse from file {calls_file}")
    
    if bouts_confidences or calls_confidences:
        plt.figure(figsize=(10, 6))
        plt.hist(bouts_confidences, bins=30, alpha=0.5, color='blue', label='Bouts')
        plt.hist(calls_confidences, bins=30, alpha=0.5, color='red', label='Calls')
        plt.title(f'YOLO Confidence Distribution for {bird_name} Hatch {hatch_number}')
        plt.xlabel('Confidence')
        plt.ylabel('Frequency')
        plt.legend(loc='upper right')
        plt.savefig(os.path.join(hatch_path, 'bout_confidence_distribution.svg'))
        plt.close()


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        
        if not os.path.isdir(hatch_path):
            continue
        
        bird_name = bird_dir
        hatch_number = hatch_folder
        
        # Plot and save the distribution of bout durations
        plot_bout_durations(hatch_path, bird_name, hatch_number)
        
        # Plot and save the distribution of YOLO confidence
        plot_yolo_confidence(hatch_path, bird_name, hatch_number)

print("Plots have been generated and saved successfully.")
# Out:
# Plots have been generated and saved successfully.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import numpy as np

# Base directory
base_dir = r'G:\Lab Dropbox\BirdSong\BirdData_2024'

# Function to plot and save the heatmap of bout duration distributions across hatch days
def plot_bout_duration_heatmap(bird_path, bird_name):
    mic_path = os.path.join(bird_path, 'mic')
    hatch_folders = [f for f in os.listdir(mic_path) if os.path.isdir(os.path.join(mic_path, f))]
    
    # Dictionary to store bout durations for each hatch day
    bout_durations = {}
    
    for hatch_folder in hatch_folders:
        hatch_path = os.path.join(mic_path, hatch_folder)
        bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_folder}.csv')
        
        if os.path.exists(bouts_file):
            try:
                bouts_df = pd.read_csv(bouts_file)
                if not bouts_df.empty:
                    bouts_df['duration'] = bouts_df['wav_file_end_time'] - bouts_df['wav_file_start_time']
                    bout_durations[hatch_folder] = bouts_df['duration'].tolist()
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    if not bout_durations:
        print(f"No valid bout data found for {bird_name}")
        return
    
    # Create a DataFrame from the dictionary
    max_duration = 6  # Limit the duration to 6 seconds
    num_bins = 20
    duration_bins = pd.cut([0, max_duration], bins=num_bins, retbins=True)[1]  # Get the bin edges
    
    heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
    
    for hatch_folder, durations in bout_durations.items():
        # Filter durations to be within 0 to 6 seconds
        filtered_durations = [d for d in durations if 0 <= d <= max_duration]
        if filtered_durations:
            duration_counts = pd.cut(filtered_durations, bins=duration_bins).value_counts()
            heatmap_data.loc[hatch_folder] = duration_counts.values
    
    # Normalize the data to represent probabilities
    heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0).fillna(0)
    
    # Plot the heatmap
    plt.figure(figsize=(12, 8))
    sns.heatmap(heatmap_data, cmap="YlGnBu", cbar_kws={'label': 'Probability'}, xticklabels=[f'{x:.2f}' for x in duration_bins[:-1]])
    plt.title(f'Bout Duration Distribution Heatmap for {bird_name}')
    plt.xlabel('Duration (seconds)')
    plt.ylabel('Hatch Day')
    # Rotate x-axis labels vertically
    plt.xticks(rotation=90)
    # Save the heatmap as a vector image
    heatmap_file = os.path.join(bird_path, 'bout_duration_heatmap.svg')
    plt.savefig(heatmap_file)
    plt.close()
    print(f"Heatmap saved for {bird_name} at {heatmap_file}")


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    bird_name = bird_dir
    
    # Plot and save the heatmap of bout duration distributions across hatch days
    plot_bout_duration_heatmap(bird_path, bird_name)

print("Heatmaps have been generated and saved successfully.")

# Function to plot and save the number of bouts detected per hatch day
def plot_bout_counts_per_hatch_day(bird_path, bird_name):
    mic_path = os.path.join(bird_path, 'mic')
    hatch_folders = [f for f in os.listdir(mic_path) if os.path.isdir(os.path.join(mic_path, f))]
    
    # Dictionary to store the number of bouts for each hatch day
    bout_counts = {}

    for hatch_folder in hatch_folders:
        hatch_path = os.path.join(mic_path, hatch_folder)
        bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_folder}.csv')
        
        if os.path.exists(bouts_file):
            try:
                bouts_df = pd.read_csv(bouts_file)
                if not bouts_df.empty:
                    # Count the number of bouts for this hatch day
                    bout_counts[hatch_folder] = len(bouts_df)
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    if not bout_counts:
        print(f"No valid bout data found for {bird_name}")
        return
    
    # Sort bout counts by hatch day
    bout_counts = {k: v for k, v in sorted(bout_counts.items(), key=lambda item: int(item[0]))}
    
    # Plot the bout counts
    plt.figure(figsize=(10, 6))
    plt.bar(bout_counts.keys(), bout_counts.values(), color='skyblue', edgecolor='black')
    plt.title(f'Number of Bouts Detected per Hatch Day for {bird_name}')
    plt.xlabel('Hatch Day')
    plt.ylabel('Number of Bouts')
    # Rotate x-axis labels vertically
    plt.xticks(rotation=90)
    # Save the figure as an SVG file
    bouts_count_svg = os.path.join(bird_path, 'bout_counts_per_hatch_day.svg')
    plt.savefig(bouts_count_svg)
    plt.close()
    print(f"SVG plot saved for {bird_name} at {bouts_count_svg}")


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    bird_name = bird_dir
    
    # Plot and save the number of bouts detected per hatch day
    plot_bout_counts_per_hatch_day(bird_path, bird_name)

print("Bout count plots have been generated and saved successfully.")

# Function to extract the hour from the filename
def extract_hour_from_filename(filename):
    # Assuming the filename format is B028_45423.68911763_5_11_19_8_31.wav
    match = re.search(r'_(\d+)_(\d+)_(\d+)_(\d+)_\d+\.wav', filename)  # Extracting the part with _5_11_19_8_31
    if match:
        hour = match.group(3)  # The third group (19 in the example) is the hour
        return int(hour)
    return None

# Function to calculate and plot the average number of bouts per hour of the day
def plot_avg_bouts_per_hour(bird_path, bird_name):
    mic_path = os.path.join(bird_path, 'mic')
    hatch_folders = [f for f in os.listdir(mic_path) if os.path.isdir(os.path.join(mic_path, f))]
    
    # Dictionary to store bout counts per hour for each hatch day
    bouts_per_hour = {hour: [] for hour in range(24)}  # A dictionary of lists to collect counts for each hatch day
    
    for hatch_folder in hatch_folders:
        hatch_path = os.path.join(mic_path, hatch_folder)
        bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_folder}.csv')
        
        if os.path.exists(bouts_file):
            try:
                bouts_df = pd.read_csv(bouts_file)
                if not bouts_df.empty:
                    # Create a temporary dictionary to count the bouts for each hour in this hatch day
                    hatch_bouts_per_hour = {hour: 0 for hour in range(24)}
                    
                    # Extract the hour from the filename for each bout and count it
                    for _, row in bouts_df.iterrows():
                        hour = extract_hour_from_filename(row['wav_filename'])
                        if hour is not None:
                            hatch_bouts_per_hour[hour] += 1  # Increment the count for the detected hour
                    
                    # Append the counts for each hour to the main bouts_per_hour dictionary
                    for hour, count in hatch_bouts_per_hour.items():
                        bouts_per_hour[hour].append(count)  # Append the count for this hour
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    # Calculate the average and standard deviation of bouts per hour across all hatch days
    avg_bouts_per_hour = []
    std_bouts_per_hour = []
    
    for hour in range(24):
        if bouts_per_hour[hour]:
            avg_bouts_per_hour.append(np.mean(bouts_per_hour[hour]))
            std_bouts_per_hour.append(np.std(bouts_per_hour[hour]))
        else:
            avg_bouts_per_hour.append(0)
            std_bouts_per_hour.append(0)
    
    # Plot the average number of bouts per hour and the standard deviation as a shadow
    hours = range(24)
    avg_bouts_per_hour = np.array(avg_bouts_per_hour)
    std_bouts_per_hour = np.array(std_bouts_per_hour)
    
    plt.figure(figsize=(10, 6))
    
    # Plot the average line
    plt.plot(hours, avg_bouts_per_hour, 'b-', label='Average Bouts')
    
    # Plot the shaded area for standard deviation
    plt.fill_between(hours, avg_bouts_per_hour - std_bouts_per_hour, avg_bouts_per_hour + std_bouts_per_hour, color='blue', alpha=0.2, label='Standard Deviation')
    
    plt.title(f'Average Number of Bouts per Hour for {bird_name}')
    plt.xlabel('Hour of the Day')
    plt.ylabel('Average Number of Bouts')
    plt.xticks(hours)
    plt.grid(True)
    
    # Save the figure as an SVG file
    avg_bouts_svg = os.path.join(bird_path, 'avg_bouts_per_hour.svg')
    plt.savefig(avg_bouts_svg)
    plt.close()
    print(f"SVG plot saved for {bird_name} at {avg_bouts_svg}")

# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    bird_name = bird_dir
    
    # Plot and save the average number of bouts per hour of the day
    plot_avg_bouts_per_hour(bird_path, bird_name)

print("Average bouts per hour plots have been generated and saved successfully.")
# Out:
# Heatmap saved for 8UWL2 at G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\bout_duration_heatmap.svg
# Heatmap saved for B028 at G:\Lab Dropbox\BirdSong\BirdData_2024\B028\bout_duration_heatmap.svg
# No valid bout data found for B033
# No valid bout data found for B045
# No valid bout data found for B17Y4
# No valid bout data found for Bk19
# No valid bout data found for Bk52W16
# No valid bout data found for BK6
# No valid bout data found for BK8W98
# No valid bout data found for EVC2303
# No valid bout data found for Gr30
# No valid bout data found for NoBa01
# No valid bout data found for NoBa02
# No valid bout data found for Or04
# No valid bout data found for OR09V022V023
# No valid bout data found for R02
# No valid bout data found for R03
# No valid bout data found for R04
# No valid bout data found for R07
# No valid bout data found for R08
# No valid bout data found for R104
# No valid bout data found for R120
# No valid bout data found for R15
# No valid bout data found for R155
# No valid bout data found for R156
# No valid bout data found for R159
# No valid bout data found for R16
# No valid bout data found for R17
# No valid bout data found for R19
# No valid bout data found for R22
# No valid bout data found for R26
# No valid bout data found for R26a
# No valid bout data found for R29
# No valid bout data found for R29B11
# No valid bout data found for R30
# No valid bout data found for R32
# No valid bout data found for R37
# No valid bout data found for R38
# No valid bout data found for R42
# No valid bout data found for R44
# No valid bout data found for R55
# No valid bout data found for R58
# No valid bout data found for R95
# No valid bout data found for R97
# No valid bout data found for W68Pi45
# Heatmaps have been generated and saved successfully.
# SVG plot saved for 8UWL2 at G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\bout_counts_per_hatch_day.svg
# SVG plot saved for B028 at G:\Lab Dropbox\BirdSong\BirdData_2024\B028\bout_counts_per_hatch_day.svg
# No valid bout data found for B033
# No valid bout data found for B045
# No valid bout data found for B17Y4
# No valid bout data found for Bk19
# No valid bout data found for Bk52W16
# No valid bout data found for BK6
# No valid bout data found for BK8W98
# No valid bout data found for EVC2303
# No valid bout data found for Gr30
# No valid bout data found for NoBa01
# No valid bout data found for NoBa02
# No valid bout data found for Or04
# No valid bout data found for OR09V022V023
# No valid bout data found for R02
# No valid bout data found for R03
# No valid bout data found for R04
# No valid bout data found for R07
# No valid bout data found for R08
# No valid bout data found for R104
# No valid bout data found for R120
# No valid bout data found for R15
# No valid bout data found for R155
# No valid bout data found for R156
# No valid bout data found for R159
# No valid bout data found for R16
# No valid bout data found for R17
# No valid bout data found for R19
# No valid bout data found for R22
# No valid bout data found for R26
# No valid bout data found for R26a
# No valid bout data found for R29
# No valid bout data found for R29B11
# No valid bout data found for R30
# No valid bout data found for R32
# No valid bout data found for R37
# No valid bout data found for R38
# No valid bout data found for R42
# No valid bout data found for R44
# No valid bout data found for R55
# No valid bout data found for R58
# No valid bout data found for R95
# No valid bout data found for R97
# No valid bout data found for W68Pi45
# Bout count plots have been generated and saved successfully.
# SVG plot saved for 8UWL2 at G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\avg_bouts_per_hour.svg
# SVG plot saved for B028 at G:\Lab Dropbox\BirdSong\BirdData_2024\B028\avg_bouts_per_hour.svg
# SVG plot saved for B033 at G:\Lab Dropbox\BirdSong\BirdData_2024\B033\avg_bouts_per_hour.svg
# SVG plot saved for B045 at G:\Lab Dropbox\BirdSong\BirdData_2024\B045\avg_bouts_per_hour.svg
# SVG plot saved for B17Y4 at G:\Lab Dropbox\BirdSong\BirdData_2024\B17Y4\avg_bouts_per_hour.svg
# SVG plot saved for Bk19 at G:\Lab Dropbox\BirdSong\BirdData_2024\Bk19\avg_bouts_per_hour.svg
# SVG plot saved for Bk52W16 at G:\Lab Dropbox\BirdSong\BirdData_2024\Bk52W16\avg_bouts_per_hour.svg
# SVG plot saved for BK6 at G:\Lab Dropbox\BirdSong\BirdData_2024\BK6\avg_bouts_per_hour.svg
# SVG plot saved for BK8W98 at G:\Lab Dropbox\BirdSong\BirdData_2024\BK8W98\avg_bouts_per_hour.svg
# SVG plot saved for EVC2303 at G:\Lab Dropbox\BirdSong\BirdData_2024\EVC2303\avg_bouts_per_hour.svg
# SVG plot saved for Gr30 at G:\Lab Dropbox\BirdSong\BirdData_2024\Gr30\avg_bouts_per_hour.svg
# SVG plot saved for NoBa01 at G:\Lab Dropbox\BirdSong\BirdData_2024\NoBa01\avg_bouts_per_hour.svg
# SVG plot saved for NoBa02 at G:\Lab Dropbox\BirdSong\BirdData_2024\NoBa02\avg_bouts_per_hour.svg
# SVG plot saved for Or04 at G:\Lab Dropbox\BirdSong\BirdData_2024\Or04\avg_bouts_per_hour.svg
# SVG plot saved for OR09V022V023 at G:\Lab Dropbox\BirdSong\BirdData_2024\OR09V022V023\avg_bouts_per_hour.svg
# SVG plot saved for R02 at G:\Lab Dropbox\BirdSong\BirdData_2024\R02\avg_bouts_per_hour.svg
# SVG plot saved for R03 at G:\Lab Dropbox\BirdSong\BirdData_2024\R03\avg_bouts_per_hour.svg
# SVG plot saved for R04 at G:\Lab Dropbox\BirdSong\BirdData_2024\R04\avg_bouts_per_hour.svg
# SVG plot saved for R07 at G:\Lab Dropbox\BirdSong\BirdData_2024\R07\avg_bouts_per_hour.svg
# SVG plot saved for R08 at G:\Lab Dropbox\BirdSong\BirdData_2024\R08\avg_bouts_per_hour.svg
# SVG plot saved for R104 at G:\Lab Dropbox\BirdSong\BirdData_2024\R104\avg_bouts_per_hour.svg
# SVG plot saved for R120 at G:\Lab Dropbox\BirdSong\BirdData_2024\R120\avg_bouts_per_hour.svg
# SVG plot saved for R15 at G:\Lab Dropbox\BirdSong\BirdData_2024\R15\avg_bouts_per_hour.svg
# SVG plot saved for R155 at G:\Lab Dropbox\BirdSong\BirdData_2024\R155\avg_bouts_per_hour.svg
# SVG plot saved for R156 at G:\Lab Dropbox\BirdSong\BirdData_2024\R156\avg_bouts_per_hour.svg
# SVG plot saved for R159 at G:\Lab Dropbox\BirdSong\BirdData_2024\R159\avg_bouts_per_hour.svg
# SVG plot saved for R16 at G:\Lab Dropbox\BirdSong\BirdData_2024\R16\avg_bouts_per_hour.svg
# SVG plot saved for R17 at G:\Lab Dropbox\BirdSong\BirdData_2024\R17\avg_bouts_per_hour.svg
# SVG plot saved for R19 at G:\Lab Dropbox\BirdSong\BirdData_2024\R19\avg_bouts_per_hour.svg
# SVG plot saved for R22 at G:\Lab Dropbox\BirdSong\BirdData_2024\R22\avg_bouts_per_hour.svg
# SVG plot saved for R26 at G:\Lab Dropbox\BirdSong\BirdData_2024\R26\avg_bouts_per_hour.svg
# SVG plot saved for R26a at G:\Lab Dropbox\BirdSong\BirdData_2024\R26a\avg_bouts_per_hour.svg
# SVG plot saved for R29 at G:\Lab Dropbox\BirdSong\BirdData_2024\R29\avg_bouts_per_hour.svg
# SVG plot saved for R29B11 at G:\Lab Dropbox\BirdSong\BirdData_2024\R29B11\avg_bouts_per_hour.svg
# SVG plot saved for R30 at G:\Lab Dropbox\BirdSong\BirdData_2024\R30\avg_bouts_per_hour.svg
# SVG plot saved for R32 at G:\Lab Dropbox\BirdSong\BirdData_2024\R32\avg_bouts_per_hour.svg
# SVG plot saved for R37 at G:\Lab Dropbox\BirdSong\BirdData_2024\R37\avg_bouts_per_hour.svg
# SVG plot saved for R38 at G:\Lab Dropbox\BirdSong\BirdData_2024\R38\avg_bouts_per_hour.svg
# SVG plot saved for R42 at G:\Lab Dropbox\BirdSong\BirdData_2024\R42\avg_bouts_per_hour.svg
# SVG plot saved for R44 at G:\Lab Dropbox\BirdSong\BirdData_2024\R44\avg_bouts_per_hour.svg
# SVG plot saved for R55 at G:\Lab Dropbox\BirdSong\BirdData_2024\R55\avg_bouts_per_hour.svg
# SVG plot saved for R58 at G:\Lab Dropbox\BirdSong\BirdData_2024\R58\avg_bouts_per_hour.svg
# SVG plot saved for R95 at G:\Lab Dropbox\BirdSong\BirdData_2024\R95\avg_bouts_per_hour.svg
# SVG plot saved for R97 at G:\Lab Dropbox\BirdSong\BirdData_2024\R97\avg_bouts_per_hour.svg
# SVG plot saved for W68Pi45 at G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\avg_bouts_per_hour.svg
# Average bouts per hour plots have been generated and saved successfully.

# %% [markdown]
# # bout Entropy analytics
#
# This script processes bird song recordings to calculate and visualize the spectral entropy of detected bouts. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `pandas`, `numpy`, `scipy`, and `matplotlib`.
#
# 2. **Define Function**:
#     - `calculate_spectral_entropy`: This function computes the spectral entropy of a given signal using the Short-Time Fourier Transform (STFT).
#
# 3. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories.
#     - It loads the results from `results_bouts.csv` if available.
#
# 5. **Process Each Bout**:
#     - For each bout in the CSV file, the corresponding WAV file is read.
#     - A region of interest (ROI) around the bout is extracted with 1-second padding.
#     - The spectral entropy of the bout signal is calculated and stored.
#
# 6. **Sort and Align Bouts**:
#     - The bouts are sorted based on their total spectral entropy.
#     - All bouts are aligned to a common signal at the start of the bout using cross-correlation.
#
# 7. **Visualize Spectral Entropy**:
#     - A figure is created where each row represents a bout, the x-axis is time, and the color represents the spectral entropy.
#     - The figure is saved as an SVG file and displayed.
#
# This script helps in analyzing and visualizing the complexity of bird songs by calculating and aligning the spectral entropy of detected bouts.

# %%
import os
import pandas as pd
import numpy as np
from scipy.io import wavfile
from scipy.signal import spectrogram
import matplotlib.pyplot as plt

# Function to calculate spectral entropy
def calculate_spectral_entropy(signal, fs, nperseg=256, noverlap=128):
    f, t, Sxx = spectrogram(signal, fs, nperseg=nperseg, noverlap=noverlap)
    Sxx_norm = Sxx / np.sum(Sxx, axis=0)
    spectral_entropy = -np.sum(Sxx_norm * np.log2(Sxx_norm + 1e-10), axis=0)
    return spectral_entropy

# Base directory
base_dir = r'C:\Users\ucsfg\Documents\Code\boutRight_v3\birdsong'

# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        
        if not os.path.isdir(hatch_path):
            continue
        
        songs_dir = os.path.join(hatch_path, 'Songs')
        noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')
        
        if not os.path.exists(songs_dir) or not os.path.exists(noise_calls_dir):
            continue
        
        # Load results from CSV
        results_csv = os.path.join(hatch_path, 'results_bouts.csv')
        if not os.path.exists(results_csv):
            continue
        
        results_df = pd.read_csv(results_csv)

        # Process each bout
        bouts = []
        for index, row in results_df.iterrows():
            wav_file = row['wav_filename']
            wav_file_path = os.path.join(songs_dir, wav_file)
            try:
                fs, data = wavfile.read(wav_file_path)
            except PermissionError as e:
                print(f"PermissionError: {e}")
                continue
            
            roi_wav_start = int(row['wav_file_start_time'] * fs)
            roi_wav_end = int(row['wav_file_end_time'] * fs)
            
            # Add 1 second padding at start and end of each bout
            start_idx = max(0, roi_wav_start - fs)
            end_idx = min(len(data), roi_wav_end + fs)
            
            bout_signal = data[start_idx:end_idx]
            spectral_entropy = calculate_spectral_entropy(bout_signal, fs)
            
            bouts.append({
                'spectral_entropy': spectral_entropy,
                'total_spectral_entropy': np.sum(spectral_entropy),
                'start_idx': start_idx,
                'end_idx': end_idx,
                'wav_file': wav_file_path
            })

        # Sort bouts based on total summed spectral entropy
        bouts.sort(key=lambda x: x['total_spectral_entropy'], reverse=True)

        # Align all bouts to the common signal at the start of the bout
        aligned_bouts = []
        reference_bout = bouts[0]['spectral_entropy']
        for bout in bouts:
            correlation = np.correlate(reference_bout, bout['spectral_entropy'], mode='full')
            shift = np.argmax(correlation) - len(reference_bout) + 1
            aligned_bout = np.roll(bout['spectral_entropy'], shift)
            aligned_bouts.append(aligned_bout)

        # Make a figure in which each row is a bout, the x-axis is time, and the color is the spectral entropy
        plt.figure(figsize=(10, len(aligned_bouts)))
        for i, aligned_bout in enumerate(aligned_bouts):
            plt.imshow(aligned_bout[np.newaxis, :], aspect='auto', cmap='viridis', extent=[0, len(aligned_bout) / fs, i, i + 1])
        
        plt.xlabel('Time (s)')
        plt.ylabel('Bout')
        plt.yticks(np.arange(len(aligned_bouts)) + 0.5, np.arange(1, len(aligned_bouts) + 1))
        plt.gca().invert_yaxis()
        plt.tight_layout()
        output_svg = os.path.join(hatch_path, 'bouts_spectral_entropy.svg')
        plt.savefig(output_svg, format='svg')
        plt.show()
